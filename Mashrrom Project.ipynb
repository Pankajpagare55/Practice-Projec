# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('mushrooms.csv')

# %%
df1
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df1.shape
# Out:
# (8124, 23)

# %%
df1.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# There Is No Null Values

# %%
df1.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# All The Coloums Name

# %%
df1['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
df1['class']=df1['class'].replace({'e':0,'p':1})
df1.head()
# Out:
#    class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      1         x           s         n       t    p               f
# 1      0         x           s         y       t    a               f
# 2      0         b           s         w       t    l               f
# 3      1         x           y         w       t    p               f
# 4      0         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df1["cap-shape"].value_counts()
# Out:
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
df1["cap-shape"]=le.fit_transform(df1["cap-shape"])

# %%
df1["cap-shape"].value_counts()
# Out:
# 5    3656
# 2    3152
# 3     828
# 0     452
# 4      32
# 1       4
# Name: cap-shape, dtype: int64

# %% [markdown]
# 'x' shape is 5 's' shape is 4 'k' shape is 3 'f' shape is 2 'c' shape is 1 'b' shape is 0.

# %%
df1['cap-surface'].value_counts()
# Out:
# y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

df1['cap-surface']=le.fit_transform(df1["cap-surface"])

# %%
df1['cap-surface'].value_counts()
# Out:
# 3    3244
# 2    2556
# 0    2320
# 1       4
# Name: cap-surface, dtype: int64

# %% [markdown]
# y' surface is 3 's' surface is 2 'g' surface is 1 'f' surface is 0.

# %%
df1['cap-color'].value_counts()
# Out:
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# u      16
# r      16
# Name: cap-color, dtype: int64

# %%
df1['cap-color']=le.fit_transform(df1["cap-color"])
df1['cap-color'].value_counts()
# Out:
# 4    2284
# 3    1840
# 2    1500
# 9    1072
# 8    1040
# 0     168
# 5     144
# 1      44
# 6      16
# 7      16
# Name: cap-color, dtype: int64

# %%
X=df1[['bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']]
for col in X:
    df1[col]=le.fit_transform(X[col])
df1.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   int64
#  1   cap-shape                 8124 non-null   int32
#  2   cap-surface               8124 non-null   int32
#  3   cap-color                 8124 non-null   int32
#  4   bruises                   8124 non-null   int32
#  5   odor                      8124 non-null   int32
#  6   gill-attachment           8124 non-null   int32
#  7   gill-spacing              8124 non-null   int32
#  8   gill-size                 8124 non-null   int32
#  9   gill-color                8124 non-null   int32
#  10  stalk-shape               8124 non-null   int32
#  11  stalk-root                8124 non-null   int32
#  12  stalk-surface-above-ring  8124 non-null   int32
#  13  stalk-surface-below-ring  8124 non-null   int32
# ...

# %% [markdown]
# All Col Has Change Obj To Int

# %%
plt.figure(figsize=(15,25))
plt1=1
for col in df1:
    if plt1<25:
        ax=plt.subplot(8,3,plt1)
        sns.scatterplot(x=col,y="class",data=df1)
        plt.xlabel(col)
        plt.ylabel("class")
    plt1=plt1+1
plt.tight_layout()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df1.corr().abs(),annot=True,annot_kws={"size":15},linewidths=True)
plt.tight_layout()

# %% [markdown]
# we analyse that there is multicolinearity between columns like 'ring-type' & 'bruishes','ring-typ'e & 'gill-color', and there is two columns that are same in dataset i.e. 'cap-surface' & 'cap-suface'

# %%
df1["veil-type"].value_counts()
# Out:
# 0    8124
# Name: veil-type, dtype: int64

# %%
df1["veil-color"].value_counts()
# Out:
# 2    7924
# 0      96
# 1      96
# 3       8
# Name: veil-color, dtype: int64

# %% [markdown]
# we analyse that veil-type column has only 0 values init. so, we an drop that column

# %%
plt.figure(figsize=(20,40))
plotno=1
for col in df1:
    if plotno<=24:
        ax=plt.subplot(12,2,plotno)
        sns.distplot(df1[col])
        plt.xlabel(col,fontsize=15)
    plotno+=1
plt.show()
# Out:
# C:\Users\AT SYSTEM\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\AT SYSTEM\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plotn=1
plt.figure(figsize=(20,25))
for col in df1:
    if plotn<25:
        ax=plt.subplot(8,3,plotn)
        sns.boxplot(df1[col],color='blue',orient='v')
        plt.ylabel(col,fontsize=15)
    plotn+=1
plt.show()
# Out:
# C:\Users\AT SYSTEM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\AT SYSTEM\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\AT SYSTEM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# 'gill-attachment','gill-spacing','stalk-root','stalk-color-above-ring','stalk-color-below-ring','veil-color','ring-number', 'poplation','habitat' these columns has outliers& are not distributed normally.

# %% [markdown]
# # Data Cleaning

# %%
df1.drop(columns=['ring-type','cap-surface','veil-type','veil-color'],inplace=True,axis=1)

# %%
df1.drop(columns="spore-print-color",axis=1,inplace=True)

# %%
#df1.drop(columns="gill-attachment",axis=1,inplace=True)

# %%
df1.shape
# Out:
# (8124, 18)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df1.corr().abs(),annot=True,annot_kws={"size":15},linewidths=True)
plt.tight_layout()

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.shape
# Out:
# (3292, 18)

# %% [markdown]
# # Removing Outliers Phasee

# %%
df1.head()
# Out:
#    class  cap-shape  cap-color  bruises  odor  gill-attachment  gill-spacing  \
# 0      1          5          4        1     6                1             0
# 1      0          5          9        1     0                1             0
# 2      0          0          8        1     3                1             0
# 3      1          5          8        1     6                1             0
# 4      0          5          3        0     5                1             1
#
#    gill-size  gill-color  stalk-shape  stalk-root  stalk-surface-above-ring  \
# 0          1           4            0           3                         2
# 1          0           4            0           2                         2
# 2          0           5            0           2                         2
# 3          1           5            0           3                         2
# 4          0           4            1           3                         2
#
# ...

# %%
from scipy.stats import zscore
zs=zscore(df1[['gill-attachment','gill-spacing','stalk-root','stalk-color-above-ring','stalk-color-below-ring','ring-number','population','habitat']])
filtered=(np.abs(zs)<3).all(axis=1)
df1=df1[filtered]

# %%
df1.shape
# Out:
# (3136, 18)

# %%
X=df1.drop("class",axis=1)
Y=df1['class']

# %%
df1.describe()
# Out:
#              class    cap-shape    cap-color      bruises         odor  \
# count  3136.000000  3136.000000  3136.000000  3136.000000  3136.000000
# mean      0.630102     3.350128     4.443878     0.377551     3.970663
# std       0.482854     1.555518     2.667671     0.484852     2.249600
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     3.000000     0.000000     2.000000
# 50%       1.000000     3.000000     4.000000     0.000000     5.000000
# 75%       1.000000     5.000000     8.000000     1.000000     5.000000
# max       1.000000     5.000000     9.000000     1.000000     8.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count           3136.0   3136.000000  3136.000000  3136.000000  3136.000000
# mean               1.0      0.103316     0.366071     4.326531     0.543367
# std                0.0      0.304420     0.481806     3.669332     0.498195
# ...

# %% [markdown]
# # Selection Features

# %%
from sklearn.feature_selection import SelectKBest,f_classif
best_feature=SelectKBest(score_func=f_classif,k=17)
fit=best_feature.fit(X,Y)
df_score=pd.DataFrame(fit.scores_,columns=['Feature_score'])
df_columns=pd.DataFrame(X.columns,columns=['Feature_Name'])
feature_score=pd.concat([df_columns,df_score],axis=1)
# Out:
# C:\Users\AT SYSTEM\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [4] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\AT SYSTEM\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw

# %%
feature_score.dtypes
# Out:
# Feature_Name      object
# Feature_score    float32
# dtype: object

# %%
top=feature_score.nlargest(17,'Feature_score')

# %%
colName=top.Feature_Name.tolist()

# %%
newX=df1[colName]
newX.head()
# Out:
#    gill-color  bruises  stalk-surface-above-ring  gill-size  stalk-root  \
# 0           4        1                         2          1           3
# 1           4        1                         2          0           2
# 2           5        1                         2          0           2
# 3           5        1                         2          1           3
# 5           5        1                         2          0           2
#
#    gill-spacing  stalk-surface-below-ring  ring-number  population  habitat  \
# 0             0                         2            1           3        5
# 1             0                         2            1           2        1
# 2             0                         2            1           2        3
# 3             0                         2            1           3        5
# 5             0                         2            1           2        1
#
#    stalk-color-above-ring  stalk-color-below-ring  stalk-shape  odor  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score,roc_curve,plot_roc_curve
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=3526)

# %%
lr=LogisticRegression()
knn=KNeighborsClassifier()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()

# %%
lr.fit(X_train,Y_train)
knn.fit(X_train,Y_train)
dt.fit(X_train,Y_train)
rf.fit(X_train,Y_train)
print("All models are trained!!")
# Out:
# C:\Users\AT SYSTEM\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# All models are trained!!

# %%
lr.score(X_test,Y_test)
knn.score(X_test,Y_test)
dt.score(X_test,Y_test)
rf.score(X_test,Y_test)
print("All models test scored are captured!!")
# Out:
# All models test scored are captured!!

# %% [markdown]
# # Checking Roc plotted Curve

# %%
dis=plot_roc_curve(dt,X_test,Y_test)
plot_roc_curve(lr,X_test,Y_test,ax=dis.ax_)
plot_roc_curve(knn,X_test,Y_test,ax=dis.ax_)
plot_roc_curve(rf,X_test,Y_test,ax=dis.ax_)
plt.legend(prop={'size':11},loc='lower right')
plt.tight_layout()

# %% [markdown]
# we aree seeing that the auc of Decision tree,Kneighbors & Random Forest Classifier is 1. whereas Logistic Regression score is 0.96
#
# So, we will use Kneighbors for model Deployment as it takes less calcution to use for model deployment

# %% [markdown]
# # Model Deployment

# %%
knn.fit(X_train,Y_train)

y_pred=knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
accuracy_score(Y_test,y_pred)
# Out:
# 0.9744897959183674

# %%
confusion_matrix(y_pred,Y_test)
# Out:
# array([[295,  18],
#        [  2, 469]], dtype=int64)

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       297
#            1       1.00      0.96      0.98       487
#
#     accuracy                           0.97       784
#    macro avg       0.97      0.98      0.97       784
# weighted avg       0.98      0.97      0.97       784

# %% [markdown]
# there is need of HyperParameter tuning
