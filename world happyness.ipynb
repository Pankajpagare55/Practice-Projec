# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('happiness.csv')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.columns.size
# Out:
# 12

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# There Is No Null Value All This Coloum

# %%
plt.figure(figsize=(20,20))
pltno=1
for col in df:
    if pltno<=12:
        ax=plt.subplot(4,3,pltno)
        sns.scatterplot(x=col,y='Happiness Score',data=df)
        plt.xlabel(col,fontsize=20)
    pltno=pltno+1
plt.show()

# %% [raw]
# 1)Less Standard Error,Generosity of the Country's Region higher the Happiness Score.
# 2)Higher Economy higher the Happiness Score.
# 3)The Country haves the more Family its Happiness Score is high.
# 4)If You have healthy, freedom,trust your Happiness Score is high
# 5)we can see the Country,Region & Happiness Rank are based on the Happiness Score. So, we can remove these columns.

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr().abs(),annot=True,linewidths=0.5,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# only standard error and generosity has only 16% co-realation with happiness score and all others are high

# %% [markdown]
# # Describe Dataset

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidths=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('Vairable Summary')
plt.show()

# %% [markdown]
# # Outcome Of Describe Dataset

# %% [markdown]
# From The Above Ploting We Are Determinig mean,Std,Min,Max value Of Each col.It Helps To Data Cleaning

# %% [raw]
# Total Num Of Rows And Col
#
# Rows=158
# col=12
#
#
# Happiness Rank	M
#     1.Mean=79.493671
#     2.Std=45.754363
#     4.Min=1.000000
#     5.Max=158.000000
# Happiness Score
#     1.Mean=5.375734
#     2.Std=1.145010
#     4.Min=2.839000
#     5.Max=7.587000
# Standard Error
#     1.Mean=0.047885
#     2.Std=0.017146
#     4.Min=0.018480
#     5.Max=0.136930
# Economy (GDP per Capita)
#     1.Mean=0.846137
#     2.Std=0.403121
#     4.Min=0.000000
#     5.Max=1.690420
# Family
#     1.Mean=0.991046
#     2.Std=0.272369
#     4.Min=0.856823
#     5.Max=1.402230
# Health (Life Expectancy)
#     1.Mean=0.630259
#     2.Std=0.247078
#     4.Min=0.000000
#     5.Max=1.025250
# Freedom
#     1.Mean=0.428615
#     2.Std=0.150693
#     4.Min=0.000000
#     5.Max=0.669730
# Trust (Government Corruption)
#     1.Mean=0.143422
#     2.Std=0.120034
#     4.Min=0.000000
#     5.Max=0.551910
# Generosity
#     1.Mean=0.237296
#     2.Std=0.126685
#     4.Min=0.000000
#     5.Max=0.795880
# Dystopia Residual
#     1.Mean=2.098977
#     2.Std=0.553550
#     4.Min=0.328580
#     5.Max=3.602140

# %% [markdown]
# Economy(GDP per Capita), Family, Health(Life Expectancy), Trust(Government Corruption), Generosity this cols min value is 0 so it is not valid so we should replace them by there respctive mean.

# %%
sns.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %% [markdown]
# It Is Not Normally Distributed.

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %% [markdown]
# It Is Not Normally Distributed

# %%
sns.distplot(df["Family"])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %% [markdown]
# It Is Not Normally Distributed

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %% [markdown]
# It Is Not Normally Distributed

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %% [markdown]
# It Is Not Normally Distributed

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %% [markdown]
# It Is Not Normally Distributed

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %% [markdown]
# It Is Not Normally Distributed

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# Normally Distributed

# %%
df.drop(['Country',"Region","Happiness Rank"],axis=1,inplace=True)

# %%
pltn=1
plt.figure(figsize=(15,20))
for col in df:
    if pltn<=12:
        ax=plt.subplot(4,3,pltn)
        sns.boxplot(df[col],color='green',orient='v')
    pltn=pltn+1
plt.show()

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Remove Outliers

# %%
from scipy.stats import zscore
zs=zscore(df[["Standard Error","Family","Trust (Government Corruption)","Generosity","Dystopia Residual"]])
filtered=(np.abs(zs)<3).all(axis=1)
df=df[filtered]

# %%
df.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       149.000000      149.000000                149.000000  149.000000
# mean          5.429611        0.046241                  0.862163    1.008623
# std           1.111256        0.014043                  0.387975    0.251890
# min           2.905000        0.018480                  0.000000    0.302850
# 25%           4.610000        0.036800                  0.593250    0.885880
# 50%           5.268000        0.043610                  0.920490    1.035160
# 75%           6.295000        0.050690                  1.159910    1.223930
# max           7.587000        0.098110                  1.563910    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                149.000000  149.000000                     149.000000
# mean                   0.638624    0.427449                       0.140405
# ...

# %% [markdown]
# After Removing Outliers The Value Is Change Of Col Now we Can Used
#
# Transforming Data Is Less Skewed And More Data Is More Distributed

# %%
features=['Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom',
       'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
from sklearn.preprocessing import PowerTransformer
scalar=PowerTransformer(method='yeo-johnson')
df[features]=scalar.fit_transform(df[features].values)
df[features]
# Out:
#      Standard Error  Economy (GDP per Capita)    Family  \
# 0         -0.950337                  1.492454  1.658880
# 1          0.378562                  1.194067  2.009125
# 2         -1.041401                  1.266612  1.730785
# 3         -0.471124                  1.695302  1.540248
# 4         -0.799032                  1.269159  1.487718
# ..              ...                       ...       ...
# 150        0.563000                 -1.052662 -1.047195
# 151       -0.068119                 -1.490349 -0.778550
# 152       -1.320810                 -1.365216 -2.087389
# 154       -0.692726                 -1.433041 -2.010443
# 156        2.178766                 -1.938747 -1.906410
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    1.469636  1.754982                       1.817625
# 1                    1.511292  1.442182                       0.329676
# 2                    1.053469  1.616037                       1.953400
# ...

# %%
plt.figure(figsize=(20,20),facecolor='w')
plotno=1
for col in df:
    if plotno<=8:
        ax=plt.subplot(2,4,plotno)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=20)
    plotno+=1
plt.show()

# %% [markdown]
# only Generosity IS Normally Distributed And Others has Some Error
#
# In Above graph the data is less skewed or more distributed in comparision with the above distributed graph

# %% [markdown]
# # Splitting The Data Into Features & Labels

# %%
X=df.drop(columns="Happiness Score",axis=1)
Y=df["Happiness Score"]

# %% [markdown]
# # Normalize The Data

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.95033703,  1.49245411,  1.65888016, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [ 0.37856182,  1.19406711,  2.00912496, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [-1.04140135,  1.26661161,  1.73078528, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [-1.32081011, -1.36521585, -2.08738878, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [-0.69272644, -1.43304072, -2.01044293, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 2.17876604, -1.93874732, -1.90641014, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %% [markdown]
# # Splitting Features And  Labels Into train & test Dataset

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X_scaled,Y,test_size=0.20,random_state=3445)

# %% [markdown]
# # Model Deployment Phase

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()

lr.fit(xtrain,ytrain)

predicted=lr.predict(xtest)

# %%
print("Accuracy of model",lr.score(xtest,predicted)*100)
# Out:
# Accuracy of model 100.0

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(ytest,predicted,color='r')
plt.xlabel("Actual Data(ytest)")
plt.ylabel('Predicted Data(ypred)')
plt.tight_layout()

# %%
df=pd.DataFrame({"Test Data":ytest,"Predicted":predicted})
df
# Out:
#      Test Data  Predicted
# 146      3.681   3.717283
# 51       5.889   5.784215
# 56       5.828   5.748152
# 90       5.057   4.754569
# 121      4.512   4.531858
# 12       7.200   7.324900
# 109      4.686   4.682025
# 10       7.278   7.357017
# 66       5.689   5.729585
# 79       5.212   5.114138
# 119      4.517   4.672656
# 92       5.007   4.944873
# 46       5.984   6.077403
# 100      4.867   4.915497
# 59       5.791   5.853560
# 55       5.833   5.837695
# 148      3.667   3.742416
# 103      4.800   4.822803
# 98       4.876   4.712116
# 151      3.587   3.596063
# 43       6.003   5.945957
# 123      4.436   4.368510
# 113      4.633   4.591775
# 89       5.073   5.000861
# 58       5.813   5.781290
# 124      4.419   4.323931
# 67       5.605   5.500285
# 81       5.192   5.110724
# 24       6.786   6.800089
# 70       5.477   5.389439

# %% [markdown]
# # Model Evaluation Process

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mse=mean_squared_error(predicted,ytest)
mae=mean_absolute_error(predicted,ytest)
rmse=np.sqrt(mean_squared_error(predicted,ytest))

print("-"*80,"\n Mean Absolute error: ",mae)
print("\n Mean Squared Error:",mse)
print("\n Root mean Squared Error:",rmse)
# Out:
# --------------------------------------------------------------------------------
#  Mean Absolute error:  0.0746655260081728
#
#  Mean Squared Error: 0.009001846401542734
#
#  Root mean Squared Error: 0.09487806069657376

# %% [markdown]
# # Saving  Model

# %%
import pickle
pickle.dump(lr,open("Practice1_model.pickle","wb"))

# %% [markdown]
# # Regularization

# %%
from sklearn.linear_model import Lasso,Ridge,LassoCV,RidgeCV

# %% [markdown]
# # L1 Form

# %%
#L1 Form
lasso=LassoCV(alphas=None,max_iter=1000,normalize=False)
lasso.fit(xtrain,ytrain)
# Out:
# LassoCV()

# %%
lasso_reg=Lasso(lasso.alpha_)
lasso_reg.fit(xtrain,ytrain)
# Out:
# Lasso(alpha=0.0009117448509698906)

# %%
lasso_reg.score(xtest,ytest)
# Out:
# 0.9892245712934457

# %% [markdown]
# # L2 Form

# %%
ridge=RidgeCV(alphas=np.arange(0.001,0.1,0.01),normalize=False)
ridge.fit(xtrain,ytrain)
ridge_reg=Ridge(alpha=ridge.alpha_)
ridge_reg.fit(xtrain,ytrain)
# Out:
# Ridge(alpha=0.09099999999999998)

# %%
ridge_reg.score(xtest,ytest)
# Out:
# 0.9892185965690294

# %% [markdown]
# L1 & L2 form of regularization gives the accuracy of our model that is similiar with model deployment. So, there is no underfitting or overfitting.
