# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.preprocessing import StandardScaler,MinMaxScaler,PowerTransformer

from sklearn.preprocessing import LabelEncoder,OneHotEncoder,OrdinalEncoder

import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import zscore


from sklearn.linear_model import LinearRegression,Lasso,LassoCV,Ridge,RidgeCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

import warnings
warnings.filterwarnings("ignore")

# %%
data_train=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/bigdatamart_rep/master/bigdatamart_Train.csv")

data_train.sample(4)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2917           DRG11        6.385          Low Fat         0.084180
# 6039           FDE35          NaN          Regular         0.000000
# 3613           NCZ06          NaN          Low Fat         0.093706
# 6718           NCS05       11.500          Low Fat         0.020961
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 2917         Hard Drinks  109.0596            OUT018
# 6039       Starchy Foods   59.8904            OUT027
# 3613           Household  253.8698            OUT027
# 6718  Health and Hygiene  133.2942            OUT013
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 2917                       2009      Medium               Tier 3
# 6039                       1985      Medium               Tier 3
# 3613                       1985      Medium               Tier 3
# 6718                       1987        High               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 2917  Supermarket Type2          1941.4728
# 6039  Supermarket Type3          1757.7120
# 3613  Supermarket Type3          3297.7074
# 6718  Supermarket Type1          2649.8840

# %% [markdown]
#  some random 4 records of training dataset.

# %%
data_test=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/bigdatamart_rep/master/bigdatamart_Test.csv")

data_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %% [markdown]
# 5 records of test data shown from the start.

# %%
data_test.shape
# Out:
# (5681, 11)

# %% [markdown]
# test data has 5681 no. of records and 11 no. of columns. In this all columns are features no target value. so this dataset will be used for test purpose.

# %%
data_train.shape
# Out:
# (8523, 12)

# %%
data_train.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data_test.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
data_train.columns.tolist()
# Out:
# ['Item_Identifier',
#  'Item_Weight',
#  'Item_Fat_Content',
#  'Item_Visibility',
#  'Item_Type',
#  'Item_MRP',
#  'Outlet_Identifier',
#  'Outlet_Establishment_Year',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'Item_Outlet_Sales']

# %% [markdown]
# Item_Outlet_Sales: Sales of the product in the particular store. This is the outcome variable to be predicted.

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# There are two columns that has null values. that columns are Item_Weight that has 7060 non-null values & Outlet_Size that has 6113 non-null values.

# %% [markdown]
# # removing null values.

# %%
Unique_ids=data_train.Item_Identifier.unique().tolist()
data_id={}
for i in Unique_ids:
    j=data_train.loc[data_train['Item_Identifier']==i].mean()
    data_id[i]=j['Item_Weight']
data_id
# Out:
# {'FDA15': 9.299999999999999,
#  'DRC01': 5.920000000000001,
#  'FDN15': 17.5,
#  'FDX07': 19.2,
#  'NCD19': 8.93,
#  'FDP36': 10.395,
#  'FDO10': 13.650000000000002,
#  'FDP10': 19.0,
#  'FDH17': 16.2,
#  'FDU28': 19.2,
#  'FDY07': 11.799999999999999,
#  'FDA03': 18.5,
#  'FDX32': 15.099999999999998,
#  'FDS46': 17.6,
#  'FDF32': 16.35,
#  'FDP49': 9.0,
#  'NCB42': 11.799999999999999,
#  'DRI11': 8.26,
#  'FDU02': 13.349999999999998,
#  'FDN22': 18.85,
#  'FDW12': 8.315,
#  'NCB30': 14.599999999999998,
#  'FDC37': 15.5,
#  'FDR28': 13.85,
#  'NCD06': 13.0,
#  'FDV10': 7.644999999999999,
#  'DRJ59': 11.65,
#  'FDE51': 5.924999999999999,
#  'FDC14': 14.5,
#  'FDV38': 19.25,
#  'NCS17': 18.6,
#  'FDP33': 18.7,
#  'FDO23': 17.849999999999998,
#  'DRH01': 17.5,
#  'NCX29': 10.0,
#  'FDV20': 20.2,
#  'DRZ11': 8.85,
#  'FDX10': 6.385,
#  'FDB34': 15.25,
#  'FDK43': 9.799999999999999,
#  'FDA46': 13.6,
#  'FDC02': 21.349999999999998,
#  'FDL50': 12.15,
#  'FDM39': 6.42,
#  'NCP05': 19.599999999999998,
#  'FDV49': 10.0,
#  'FDL12': 15.85,
#  'FDS02': 10.195,
#  'NCL17': 7.39,
#  'FDM40': 10.195,
#  'FDR13': 9.895,
#  'FDA43': 10.895,
#  'NCP18': 12.150000000000002,
#  'FDK21': 7.905,
#  'NCX54': 9.195000000000002,
#  'DRK35': 8.365,
#  'FDY21': 15.1,
#  'FDI26': 5.9399999999999995,
#  'FDM20': 10.0,
#  'FDV27': 7.97,
#  'FDF09': 6.215,
#  'FDY40': 15.5,
#  'FDY45': 17.5,
#  'FDC46': 17.7,
#  'FDH19': 19.349999999999998,
#  'FDZ03': 13.65,
#  'DRH37': 17.599999999999998,
#  'NCI17': 8.644999999999998,
#  'FDJ58': 15.599999999999998,
#  'FDH35': 18.25,
#  'FDG02': 7.855000000000001,
#  'NCZ18': 7.825000000000001,
#  'FDC29': 8.39,
#  'FDQ10': 12.849999999999998,
#  'FDN48': 13.35,
#  'FDL04': 19.0,
#  'FDV25': 5.905,
#  'FDD58': 7.759999999999999,
#  'FDN04': 11.799999999999999,
#  'FDV45': 16.75,
#  'NCL18': 18.849999999999998,
#  'FDR12': 12.6,
#  'FDG20': 15.5,
#  'FDZ55': 6.055,
#  'FDQ49': 20.2,
#  'FDN33': 6.305,
#  'FDN27': 20.85,
#  'FDW20': 20.75,
#  'DRG27': 8.895,
#  'DRI25': 19.599999999999998,
#  'FDA44': 19.7,
#  'NCR17': 9.799999999999999,
#  'FDU04': 7.93,
#  'FDF41': 12.15,
#  'FDB56': 8.75,
#  'FDT28': 13.299999999999999,
#  'FDD10': 20.599999999999998,
#  'FDW57': 8.31,
#  'DRB48': 16.75,
#  'FDP09': 19.75,
#  'FDH14': 17.099999999999998,
#  'FDA47': 10.5,
#  'FDG12': 6.634999999999999,
#  'DRE60': 9.394999999999998,
#  'DRK49': 14.150000000000002,
#  'FDD03': 13.3,
#  'FDS52': 8.89,
#  'FDW39': 6.69,
#  'FDX34': 6.195,
#  'FDV11': 9.1,
#  'FDD17': 7.5,
#  'FDZ16': 16.849999999999998,
#  'FDZ46': 7.485,
#  'DRA12': 11.6,
#  'FDY58': 11.65,
#  'NCF19': 13.0,
#  'DRJ13': 12.65,
#  'FDB14': 20.25,
#  'FDJ38': 8.6,
#  'FDW11': 12.6,
#  'FDL40': 17.7,
#  'DRI49': 14.15,
#  'DRG23': 8.88,
#  'NCP30': 20.5,
#  'FDY25': 12.0,
#  'NCH54': 13.5,
#  'NCR53': 12.150000000000002,
#  'NCO26': 7.235,
#  'FDB51': 6.920000000000001,
#  'FDX44': 9.299999999999999,
#  'NCN07': 18.5,
#  'NCC31': 8.02,
#  'NCO55': 12.8,
#  'NCC30': 16.6,
#  'FDI16': 14.0,
#  'FDP16': 18.6,
#  'FDB11': 16.0,
#  'NCB06': 17.6,
#  'FDA45': 21.25,
#  'DRJ25': 14.6,
#  'FDI04': 13.650000000000002,
#  'DRK12': 9.5,
#  'FDX20': 7.365000000000001,
#  'NCI18': 18.349999999999998,
#  'FDB36': 5.464999999999999,
#  'FDN13': 18.599999999999998,
#  'DRD24': 13.849999999999998,
#  'FDQ28': 14.0,
#  'FDM22': 14.0,
#  'FDR07': 21.35,
#  'DRF49': 7.269999999999999,
#  'FDW51': 6.155,
#  'DRL01': 19.5,
#  'FDP25': 15.200000000000001,
#  'NCM43': 14.5,
#  'FDK44': 16.6,
#  'FDM15': 11.799999999999999,
#  'FDS31': 13.099999999999998,
#  'FDI32': 17.7,
#  'FDR47': 17.85,
#  'FDB35': 12.299999999999999,
#  'NCU05': 11.799999999999999,
#  'DRY23': 9.394999999999998,
#  'FDO24': 11.099999999999998,
#  'FDV39': 11.299999999999999,
#  'NCO17': 10.0,
#  'FDU50': 5.75,
#  'FDT12': 6.214999999999999,
#  'FDK58': 11.349999999999998,
#  'FDO08': 11.1,
#  'NCW29': 14.0,
#  'FDE04': 19.75,
#  'NCB19': 6.5249999999999995,
#  'FDV15': 10.299999999999999,
#  'FDL58': 5.78,
#  'FDA08': 11.85,
#  'FDT43': 16.349999999999998,
#  'NCX06': 17.6,
#  'FDT20': 10.5,
#  'FDB41': 19.0,
#  'NCN55': 14.6,
#  'FDE40': 15.6,
#  'FDX49': 4.615,
#  'NCM53': 18.75,
#  'FDE36': 5.259999999999999,
#  'FDN57': 18.25,
#  'FDI24': 10.3,
#  'FDI19': 15.1,
#  'FDF24': 15.5,
#  'FDG52': 13.65,
#  'DRF36': 16.099999999999998,
#  'FDS45': 5.175,
#  'FDX40': 12.849999999999998,
#  'DRC27': 13.799999999999999,
#  'NCD30': 19.7,
#  'NCZ54': 14.650000000000002,
#  'FDE10': 6.670000000000001,
#  'FDR44': 6.11,
#  'FDP28': 13.650000000000002,
#  'FDX15': 17.2,
#  'FDA39': 6.32,
#  'FDY24': 4.88,
#  'FDC60': 5.425,
#  'FDH28': 15.849999999999998,
#  'FDT25': 7.5,
#  'NCO07': 9.06,
#  'DRF27': 8.93,
#  'FDS49': 9.0,
#  'FDX25': 16.7,
#  'NCX42': 6.36,
#  'FDG33': 5.365000000000001,
#  'FDL56': 14.1,
#  'FDF14': 7.55,
#  'DRM47': 9.299999999999999,
#  'FDX21': 7.049999999999999,
#  'NCR38': 17.25,
#  'NCR18': 15.85,
#  'NCU41': 18.85,
#  'FDY56': 16.349999999999998,
#  'DRJ51': 14.1,
#  'FDU44': 12.15,
#  'FDL43': 10.1,
#  'FDF05': 17.5,
#  'DRF15': 18.35,
#  'FDL20': 17.099999999999998,
#  'FDV32': 7.784999999999999,
#  'FDJ34': 11.799999999999999,
#  'FDG08': 13.150000000000002,
#  'FDQ04': 6.400000000000001,
#  'FDW13': 8.5,
#  'FDY03': 17.599999999999998,
#  'FDS12': 9.1,
#  'FDJ55': 12.799999999999999,
#  'DRK01': 7.63,
#  'FDG28': 9.285,
#  'FDY38': 13.6,
#  'FDN01': 8.894999999999998,
#  'NCR54': 16.35,
#  'FDG29': 17.599999999999998,
#  'FDG24': 7.9750000000000005,
#  'FDG59': 15.85,
#  'FDM28': 15.700000000000001,
#  'FDW04': 8.985,
#  'FDS26': 20.35,
#  'FDQ56': 6.590000000000002,
#  'FDK51': 19.849999999999998,
#  'FDL22': 16.849999999999998,
#  'FDY55': 16.75,
#  'FDZ10': 17.849999999999998,
#  'FDZ32': 7.785,
#  'NCF07': 9.0,
#  'DRE49': 20.75,
#  'FDJ08': 11.1,
#  'FDT39': 6.26,
#  'FDE08': 18.2,
#  'FDB57': 20.25,
#  'NCT54': 8.695,
#  'FDM25': 10.695,
#  'FDF20': 12.85,
#  'FDH27': 7.075000000000001,
#  'FDV60': 20.2,
#  'FDY59': 8.195,
#  'FDK36': 7.090000000000001,
#  'NCM31': 6.095,
#  'FDE33': 19.349999999999998,
#  'FDU36': 6.1499999999999995,
#  'FDV13': 17.35,
#  'NCQ54': 17.7,
#  'DRP47': 15.75,
#  'FDB21': 7.475,
#  'FDR04': 7.075000000000001,
#  'FDX23': 6.445,
#  'FDX19': 19.099999999999998,
#  'FDD40': 20.25,
#  'FDA01': 15.0,
#  'FDS33': 6.670000000000001,
#  'FDM50': 13.0,
#  'FDB29': 16.7,
#  'FDF46': 7.07,
#  'FDA33': 6.480000000000001,
#  'FDC08': 19.0,
#  'FDB53': 13.35,
#  'FDY31': 5.9799999999999995,
#  'DRQ35': 9.299999999999999,
#  'FDX36': 9.695000000000002,
#  'DRD13': 15.0,
#  'FDC52': 11.15,
#  'FDB45': 20.849999999999998,
#  'NCK19': 9.799999999999999,
#  'FDV51': 16.349999999999998,
#  'FDZ35': 9.6,
#  'NCW17': 18.0,
#  'FDV59': 13.35,
#  'DRH39': 20.7,
#  'FDN60': 15.099999999999998,
#  'FDU55': 16.2,
#  'FDN58': 13.799999999999999,
#  'FDC41': 15.599999999999998,
#  'FDO01': 21.1,
#  'NCO43': 5.5,
#  'FDQ07': 15.1,
#  'FDF28': 15.699999999999998,
#  'FDM01': 7.894999999999999,
#  'FDY49': 17.2,
#  'FDR24': 17.35,
#  'NCY18': 7.284999999999998,
#  'NCY30': 20.25,
#  'FDJ22': 18.75,
#  'DRI37': 15.85,
#  'FDL27': 6.17,
#  'NCO30': 19.5,
#  'NCB07': 19.2,
#  'FDP59': 20.85,
#  'FDR59': 14.5,
#  'FDT27': 11.395,
#  'DRI01': 7.97,
#  'FDU09': 7.71,
#  'FDH26': 19.25,
#  'FDN39': 19.349999999999998,
#  'FDH40': 11.6,
#  'FDJ56': 8.985,
#  'DRN47': 12.099999999999998,
#  'FDX60': 14.35,
#  'FDT22': 10.395,
#  'FDX26': 17.7,
#  'FDG45': 8.1,
#  'FDD44': 8.049999999999999,
#  'FDS15': 9.195,
#  'FDL51': 20.7,
#  'FDL32': 15.7,
#  'FDZ07': 15.1,
#  'NCW53': 18.349999999999998,
#  'NCA54': 16.5,
#  'FDX09': 9.0,
#  'FDO51': 6.785,
#  'FDW49': 19.5,
#  'FDB27': 7.575,
#  'FDF45': 18.2,
#  'FDV02': 16.75,
#  'FDY28': 7.47,
#  'FDX31': 20.349999999999998,
#  'FDR43': 18.2,
#  'FDP51': 13.85,
#  'FDL52': 6.634999999999999,
#  'FDC50': 15.849999999999998,
#  'FDT57': 15.200000000000001,
#  'FDP22': 14.65,
#  'FDY32': 7.605,
#  'FDW07': 18.0,
#  'NCF18': 18.35,
#  'FDG35': 21.2,
#  'FDY34': 10.5,
#  'NCE19': 8.97,
#  'NCK31': 10.895000000000001,
#  'NCJ29': 10.6,
#  'FDT59': 13.65,
#  'NCX41': 19.0,
#  'FDU45': 15.6,
#  'FDW24': 6.799999999999999,
#  'FDF22': 6.865000000000001,
#  'FDM60': 10.8,
#  'FDR02': 16.7,
#  'DRP35': 18.849999999999998,
#  'FDS48': 15.15,
#  'NCZ42': 10.5,
#  'FDZ38': 17.599999999999998,
#  'NCB55': 15.7,
#  'FDC15': 18.1,
#  'FDF11': 10.195,
#  'FDW35': 10.6,
#  'FDB44': 6.654999999999999,
#  'NCC06': 19.0,
#  'FDB17': 13.150000000000002,
#  'FDW43': 20.1,
#  'FDA27': 20.35,
#  'FDN32': 17.5,
#  'FDZ27': 7.935,
#  'FDW23': 5.765,
#  'FDU01': 20.25,
#  'FDF10': 15.5,
#  'DRH03': 17.25,
#  'FDW27': 5.86,
#  'DRI13': 15.35,
#  'NCR05': 10.1,
#  'FDI35': 14.0,
#  'FDX08': 12.85,
#  'NCJ18': 12.349999999999998,
#  'FDJ41': 6.8500000000000005,
#  'FDU08': 10.3,
#  'FDS09': 8.895,
#  'DRH15': 8.775,
#  'NCV17': 18.85,
#  'NCO54': 19.5,
#  'FDE24': 14.85,
#  'FDH53': 20.5,
#  'FDZ13': 7.84,
#  'FDW28': 18.25,
#  'FDU46': 10.299999999999999,
#  'NCE43': 12.5,
#  'NCC42': 15.0,
#  'FDQ20': 8.325,
#  'FDA13': 15.849999999999998,
#  'FDZ15': 13.099999999999998,
#  'NCV42': 6.260000000000001,
#  'DRI51': 17.25,
#  'FDO28': 5.765,
#  'NCS54': 13.599999999999998,
#  'FDH16': 10.5,
#  'FDR52': 12.650000000000002,
#  'NCH06': 12.3,
#  'FDA36': 5.985,
#  'FDU56': 16.85,
#  'FDT09': 15.15,
#  'FDU25': 12.349999999999998,
#  'FDK41': 14.299999999999999,
#  'FDM24': 6.135,
#  'FDQ45': 9.5,
#  'DRK59': 8.894999999999998,
#  'FDR21': 19.7,
#  'FDT44': 16.6,
#  'FDX14': 13.1,
#  'FDH57': 10.894999999999998,
#  'NCT41': 15.7,
#  'FDO11': 8.0,
#  'NCP42': 8.51,
#  'FDN09': 14.15,
#  'FDP32': 6.65,
#  'FDV57': 15.25,
#  'FDR56': 15.5,
#  'FDA40': 16.0,
#  'NCG42': 19.2,
#  'NCK54': 12.15,
#  'FDE16': 8.894999999999998,
#  'FDB15': 10.894999999999998,
#  'FDC40': 16.0,
#  'FDE53': 10.895,
#  'FDK24': 9.195,
#  'FDW31': 11.35,
#  'NCM07': 9.394999999999998,
#  'DRN36': 15.199999999999998,
#  'FDQ37': 20.75,
#  'FDK28': 5.695,
#  'FDL48': 19.349999999999998,
#  'DRL23': 18.35,
#  'DRD37': 9.799999999999999,
#  'FDZ47': 20.7,
#  'NCJ54': 9.895,
#  'FDD08': 8.299999999999999,
#  'NCN18': 8.895,
#  'NCI29': 8.6,
#  'NCE06': 5.825,
#  'FDU52': 7.56,
#  'FDN16': 12.6,
#  'NCM55': 15.6,
#  'FDR49': 8.71,
#  'FDA16': 6.695,
#  'FDO19': 17.7,
#  'FDO04': 16.6,
#  'NCL19': 15.35,
#  'FDR60': 14.299999999999999,
#  'FDV37': 13.0,
#  'FDG53': 10.0,
#  'DRG01': 14.800000000000002,
#  'FDB38': 19.5,
#  'FDI27': 8.71,
#  'FDD29': 12.150000000000002,
#  'NCR41': 17.849999999999998,
#  'FDW44': 9.5,
#  'FDU21': 11.799999999999999,
#  'FDI14': 14.099999999999998,
#  'FDW50': 13.099999999999998,
#  'FDT31': 19.75,
#  'FDJ14': 10.3,
#  'NCQ43': 17.75,
#  'FDZ22': 9.395,
#  'FDU38': 10.799999999999999,
#  'FDS32': 17.75,
#  'DRH13': 8.575,
#  'DRF03': 19.099999999999998,
#  'FDJ20': 20.7,
#  'FDE22': 9.695,
#  'FDX22': 6.785,
#  'DRM11': 6.57,
#  'FDL25': 6.919999999999999,
#  'FDT08': 13.65,
#  'FDO22': 13.5,
#  'NCM41': 16.5,
#  'FDJ21': 16.7,
#  'FDC53': 8.68,
#  'FDQ09': 7.235,
#  'DRE25': 15.35,
#  'FDL08': 10.799999999999999,
#  'FDW03': 5.63,
#  'FDC17': 12.150000000000002,
#  'FDE34': 9.195,
#  'FDO44': 12.6,
#  'NCF31': 9.13,
#  'FDG14': 9.0,
#  'NCH30': 17.099999999999998,
#  'FDR36': 6.715000000000001,
#  'NCJ30': 5.82,
#  'FDR08': 18.7,
#  'NCQ50': 18.75,
#  'FDL46': 20.349999999999998,
#  'DRK37': 5.0,
#  'FDK48': 7.445,
#  'FDV58': 20.85,
#  'FDZ52': 19.2,
#  'NCF42': 17.349999999999998,
#  'FDQ48': 14.299999999999999,
#  'FDR58': 6.674999999999999,
#  'NCE07': 8.18,
#  'FDK14': 6.980000000000001,
#  'FDC11': 20.5,
#  'NCQ41': 14.8,
#  'FDX46': 12.299999999999999,
#  'FDC35': 7.435,
#  'FDH45': 15.1,
#  'FDX33': 9.195,
#  'DRJ35': 10.1,
#  'FDP13': 8.1,
#  'FDP24': 20.599999999999998,
#  'NCQ42': 20.349999999999998,
#  'FDU14': 17.75,
#  'FDT32': 19.0,
#  'FDK20': 12.599999999999998,
#  'FDU13': 8.355000000000002,
#  'FDE05': 10.894999999999998,
#  'FDE58': 18.5,
#  'FDZ01': 8.975,
#  'FDM08': 10.1,
#  'FDS58': 9.285,
#  'FDZ26': 11.599999999999998,
#  'FDY51': 12.5,
#  'FDL34': 16.0,
#  'DRG39': 14.15,
#  'NCG43': 20.2,
#  'FDT01': 13.65,
#  'DRF01': 5.655,
#  'FDF53': 20.75,
#  'FDR20': 20.0,
#  'FDD38': 16.75,
#  'FDH32': 12.799999999999999,
#  'NCJ42': 19.75,
#  'FDW22': 9.695,
#  'FDE32': 20.7,
#  'FDA34': 11.5,
#  'FDG38': 8.975,
#  'NCE31': 7.670000000000001,
#  'FDS19': 13.799999999999999,
#  'FDU11': 4.785,
#  'FDL02': 20.0,
#  'DRK23': 8.395,
#  'FDO27': 6.175,
#  'FDB16': 8.21,
#  'NCB18': 19.599999999999998,
#  'NCL53': 7.5,
#  'FDR16': 5.845,
#  'NCQ05': 11.394999999999998,
#  'FDF44': 7.17,
#  'FDK15': 10.799999999999999,
#  'FDS10': 19.2,
#  'FDU32': 8.784999999999998,
#  'FDG09': 20.599999999999998,
#  'FDE39': 7.89,
#  'NCH55': 16.349999999999998,
#  'FDC33': 8.96,
#  'NCV54': 11.099999999999998,
#  'NCQ02': 12.6,
#  'NCU17': 5.32,
#  'NCZ06': 19.599999999999998,
#  'DRH25': 18.7,
#  'NCI43': 19.849999999999998,
#  'NCQ53': 17.599999999999998,
#  'NCT18': 14.6,
#  'FDM14': 13.800000000000002,
#  'FDX57': 17.25,
#  'NCV05': 10.1,
#  'FDX39': 14.3,
#  'FDA23': 9.799999999999999,
#  'NCV06': 11.299999999999999,
#  'DRI39': 13.8,
#  'FDH21': 10.394999999999998,
#  'FDR26': 20.7,
#  'FDA14': 16.1,
#  'FDG21': 17.349999999999998,
#  'NCQ38': 16.349999999999998,
#  'FDN20': 19.35,
#  'NCN29': 15.2,
#  'FDI28': 14.299999999999999,
#  'FDZ28': 20.0,
#  'FDO52': 11.599999999999998,
#  'FDU10': 10.1,
#  'FDS28': 8.18,
#  'FDJ03': 12.35,
#  'FDQ51': 16.0,
#  'NCK06': 5.03,
#  'FDY09': 15.6,
#  'FDA10': 20.349999999999998,
#  'FDO34': 17.7,
#  'FDE38': 6.52,
#  'FDF40': 20.25,
#  'FDY02': 8.945,
#  'FDS03': 7.825,
#  'FDB59': 18.25,
#  'FDO15': 16.75,
#  'FDV56': 16.1,
#  'FDY26': 20.6,
#  'DRE13': 6.28,
#  'FDD50': 18.849999999999998,
#  'FDC04': 15.6,
#  'NCR29': 7.565,
#  'FDZ04': 9.31,
#  'FDU16': 19.25,
#  'FDV07': 9.5,
#  'FDW01': 14.5,
#  'FDC10': 9.8,
#  'DRC12': 17.85,
#  'DRK39': 7.019999999999999,
#  'DRB25': 12.299999999999999,
#  'FDK26': 5.46,
#  'FDM52': 15.1,
#  'NCO06': 19.25,
#  'FDK34': 13.35,
#  'FDO45': 13.15,
#  'FDF08': 14.299999999999999,
#  'FDH58': 12.299999999999999,
#  'FDE02': 8.71,
#  'FDR23': 15.849999999999998,
#  'FDY35': 17.599999999999998,
#  'FDG44': 6.13,
#  'FDQ23': 6.55,
#  'FDY22': 16.5,
#  'NCN41': 17.0,
#  'FDO36': 19.7,
#  'FDH20': 16.099999999999998,
#  'FDN12': 15.599999999999998,
#  'FDB09': 16.25,
#  'FDA09': 13.35,
#  'FDL24': 10.299999999999999,
#  'FDP03': 5.1499999999999995,
#  'FDO13': 7.865,
#  'DRD49': 9.895,
#  'FDQ15': 20.349999999999998,
#  'NCP50': 17.349999999999998,
#  'FDN23': 6.575,
#  'FDS44': 12.65,
#  'NCI54': 15.200000000000001,
#  'FDA21': 13.65,
#  'FDI41': 18.5,
#  'FDE35': 7.06,
#  'DRJ24': 11.799999999999999,
#  'NCK17': 11.0,
#  'FDD36': 13.3,
#  'DRD60': 15.700000000000001,
#  'NCM19': 12.65,
#  'FDV12': 16.7,
#  'FDQ31': 5.785,
#  'FDK55': 18.5,
#  'DRG15': 6.13,
#  'FDV01': 19.2,
#  'FDT21': 7.420000000000001,
#  'FDT10': 16.7,
#  'FDN02': 16.5,
#  'FDJ40': 13.6,
#  'DRE27': 11.85,
#  'FDS27': 10.195000000000002,
#  'DRM59': 5.880000000000001,
#  'NCV30': 20.2,
#  'FDA51': 8.05,
#  'FDM46': 7.365,
#  'FDK02': 12.5,
#  'FDJ57': 7.420000000000001,
#  'FDJ45': 17.75,
#  'NCB31': 6.235,
#  'FDT50': 6.75,
#  'NCY41': 16.75,
#  'FDJ60': 19.349999999999998,
#  'FDS21': 19.85,
#  'FDQ08': 15.700000000000001,
#  'FDS47': 16.75,
#  'DRM48': 15.2,
#  'FDW46': 13.0,
#  'FDU40': 20.849999999999998,
#  'DRE12': 4.59,
#  'FDX35': 5.035,
#  'FDD51': 11.15,
#  'FDY27': 6.38,
#  'NCN06': 8.39,
#  'FDR57': 5.675,
#  'FDR19': 13.5,
#  'FDJ33': 8.895,
#  'FDA52': 16.2,
#  'FDZ08': 12.5,
#  'FDR27': 15.099999999999998,
#  'NCK42': 7.475,
#  'FDZ12': 9.17,
#  'NCI31': 20.0,
#  'FDX16': 17.849999999999998,
#  'NCA05': 20.75,
#  'DRG51': 12.1,
#  'NCR30': 20.599999999999998,
#  'FDM56': 16.7,
#  'DRM37': 15.349999999999998,
#  'FDN56': 5.46,
#  'FDO49': 10.6,
#  'FDC09': 15.5,
#  'NCZ41': 19.85,
#  'FDP19': 11.5,
#  'FDQ24': 15.7,
#  'DRL11': 10.5,
#  'FDN52': nan,
#  'FDF21': 10.299999999999999,
#  'FDS51': 13.35,
#  'FDE45': 12.1,
#  'FDX50': 20.099999999999998,
#  'NCN14': 19.099999999999998,
#  'FDQ21': 21.25,
#  'FDL38': 13.799999999999999,
#  'DRL37': 15.5,
#  'FDZ39': 19.7,
#  'FDH10': 21.0,
#  'FDS35': 9.299999999999999,
#  'FDN21': 18.599999999999998,
#  'NCO18': 13.15,
#  'FDD05': 19.349999999999998,
#  'FDX59': 10.195,
#  'FDZ23': 17.75,
#  'FDX27': 20.7,
#  'FDR14': 11.65,
#  'FDZ56': 16.25,
#  'NCL55': 12.15,
#  'FDD59': 10.5,
#  'DRF23': 4.61,
#  'FDT49': 7.0,
#  'FDH22': 6.405,
#  'FDT34': 9.299999999999999,
#  'FDB39': 11.6,
#  'FDQ22': 16.75,
#  'NCN43': 12.15,
#  'FDG57': 14.700000000000001,
#  'FDU22': 12.35,
#  'NCC43': 7.389999999999999,
#  'FDP01': 20.75,
#  'FDF52': 9.299999999999999,
#  'FDZ33': 10.195,
#  'FDP48': 7.519999999999999,
#  'FDW56': 7.68,
#  'FDC26': 10.195,
#  'FDF34': 9.299999999999999,
#  'FDD04': 16.0,
#  'NCJ31': 19.2,
#  'FDO57': 20.75,
#  'FDM36': 11.650000000000002,
#  'NCY05': 13.5,
#  'DRK11': 8.21,
#  'NCL30': 18.1,
#  'DRJ39': 20.25,
#  'NCP06': 20.7,
#  'FDZ44': 8.185,
#  'FDV46': 18.2,
#  'DRG03': 14.5,
#  'FDU37': 9.5,
#  'FDI57': 19.849999999999998,
#  'FDM45': 8.655,
#  'FDB26': 14.0,
#  'FDZ25': 15.700000000000001,
#  'NCN26': 10.85,
#  'FDO38': 17.25,
#  'FDG31': 12.15,
#  'FDI45': 13.099999999999998,
#  'FDE17': 20.099999999999998,
#  'NCG06': 16.35,
#  'FDQ57': 7.275,
#  'NCP29': 8.42,
#  'FDM02': 12.5,
#  'FDR46': 16.849999999999998,
#  'FDE50': 19.7,
#  'FDS16': 15.150000000000002,
#  'FDU15': 13.65,
#  'FDO09': 13.5,
#  'FDB40': 17.5,
#  'DRN11': 7.85,
#  'FDF04': 17.5,
#  'FDE41': 9.195,
#  'FDW08': 12.1,
#  'NCD54': 21.099999999999998,
#  'FDN34': 15.6,
#  'FDL39': 16.099999999999998,
#  'FDH33': 12.849999999999998,
#  'DRH23': 14.65,
#  'FDD21': 10.299999999999999,
#  'FDK60': 16.5,
#  'FDY12': 9.8,
#  'FDP11': 15.849999999999998,
#  'FDC21': 14.6,
#  'NCF54': 18.0,
#  'FDV43': 16.0,
#  'DRC36': 13.0,
#  'NCW42': 18.2,
#  'FDL13': 13.849999999999998,
#  'FDV22': 14.85,
#  'NCB43': 20.2,
#  'FDQ46': 7.509999999999999,
#  'FDC44': 15.6,
#  'FDB22': 8.02,
#  'FDV23': 11.0,
#  'FDK10': 5.785,
#  'FDL33': 7.235,
#  'FDD20': 14.15,
#  'NCM54': 17.7,
#  'FDW48': 18.0,
#  'NCM06': 7.4750000000000005,
#  'FDT46': 11.349999999999998,
#  'FDT38': 18.7,
#  'FDO40': 17.099999999999998,
#  'FDP12': 9.8,
#  'FDI44': 16.1,
#  'FDG16': 15.25,
#  'FDY11': 6.709999999999999,
#  'FDY60': 10.5,
#  'NCM05': 6.825,
#  'FDA49': 19.7,
#  'FDY52': 6.365000000000001,
#  'FDJ02': 17.2,
#  'FDW40': 14.0,
#  'FDY08': 9.395,
#  'FDM21': 20.2,
#  'NCM42': 6.13,
#  'NCD07': 9.1,
#  'FDD09': 13.5,
#  'DRH59': 10.800000000000002,
#  'DRA24': 19.349999999999998,
#  'FDY36': 12.299999999999999,
#  'FDG34': 11.5,
#  'FDK22': 9.8,
#  'FDO33': 14.75,
#  'FDD46': 6.035,
#  'FDU34': 18.25,
#  'FDA26': 7.855000000000001,
#  'FDP38': 10.1,
#  'FDA50': 16.25,
#  'FDY10': 17.599999999999998,
#  'FDT19': 7.590000000000001,
#  'FDA28': 16.099999999999998,
#  'FDB05': 5.155,
#  'FDK45': 11.65,
#  'FDR48': 11.650000000000002,
#  'FDY15': 18.25,
#  'FDM51': 11.799999999999999,
#  'FDW09': 13.650000000000002,
#  'FDV44': 8.365,
#  'NCP43': 17.75,
#  'FDL26': 18.0,
#  'DRM35': 9.695,
#  'DRD15': 10.6,
#  'FDV04': 7.825000000000001,
#  'FDG46': 8.63,
#  'NCN05': 8.235,
#  'FDO58': 19.599999999999998,
#  'DRH49': 19.7,
#  'NCZ05': 8.485,
#  'NCP54': 15.35,
#  'FDF57': 14.5,
#  'FDA02': 14.0,
#  'DRJ37': 10.800000000000002,
#  'NCP55': 14.65,
#  'FDW45': 18.0,
#  'FDK38': 6.6499999999999995,
#  'NCZ30': 6.590000000000002,
#  'FDK08': 9.195000000000002,
#  'NCG19': 20.25,
#  'FDQ01': 19.7,
#  'FDL44': 18.25,
#  'DRM23': 16.599999999999998,
#  'NCE18': 10.0,
#  'DRZ24': 7.534999999999999,
#  'FDT48': 4.920000000000001,
#  'DRG11': 6.385,
#  'FDP60': 17.349999999999998,
#  'FDC32': 18.35,
#  'NCH18': 9.299999999999999,
#  'DRE37': 13.5,
#  'DRC13': 8.26,
#  'FDG47': 12.799999999999999,
#  'NCT05': 10.895,
#  'FDN50': 16.85,
#  'FDU60': 20.0,
#  'FDX02': 16.0,
#  'NCO41': 12.5,
#  'FDQ59': 9.8,
#  'NCZ53': 9.6,
#  'FDD34': 7.945,
#  'FDY43': 14.85,
#  'FDN44': 13.15,
#  'FDD32': 17.7,
#  'FDA56': 9.21,
#  'FDT13': 14.85,
#  'NCY29': 13.650000000000002,
#  'NCA42': 6.965000000000001,
#  'FDG26': 18.849999999999998,
#  'FDH24': 20.7,
#  'FDT52': 9.695,
#  'FDT04': 17.25,
#  'NCL54': 12.6,
#  'FDQ32': 17.849999999999998,
#  'FDE29': 8.905,
#  'FDB37': 20.25,
#  'FDN46': 7.21,
#  'FDV28': 16.099999999999998,
#  'FDW37': 19.2,
#  'FDV40': 17.35,
#  'FDZ57': 10.0,
#  'FDY46': 18.6,
#  'FDX45': 16.75,
#  'FDB33': 17.75,
#  'FDT58': 9.0,
#  'NCL31': 7.389999999999999,
#  'FDJ44': 12.299999999999999,
#  'FDS50': 17.0,
#  'FDO50': 16.25,
#  'FDU20': 19.349999999999998,
#  'DRK13': 11.799999999999999,
#  'FDI20': 19.099999999999998,
#  'FDG17': 6.865,
#  'NCK29': 5.615000000000001,
#  'FDM32': 20.5,
#  'FDC51': 10.895,
#  'FDF16': 7.299999999999999,
#  'FDI46': 9.5,
#  'FDZ21': 17.599999999999998,
#  'FDR32': 6.78,
#  'DRF25': 9.0,
#  'FDH05': 14.35,
#  'FDD52': 18.25,
#  'FDR55': 12.150000000000002,
#  'FDP04': 15.35,
#  'FDQ14': 9.27,
#  'DRN59': 15.0,
#  'NCR06': 12.5,
#  'FDB58': 10.5,
#  'NCV41': 14.349999999999996,
#  'FDW19': 12.349999999999998,
#  'FDO56': 10.195,
#  'FDN10': 11.5,
#  'FDY20': 12.5,
#  'FDV34': 10.695,
#  'NCX18': 14.150000000000002,
#  'NCZ17': 12.15,
#  'FDD57': 18.099999999999998,
#  'FDZ48': 17.75,
#  'FDZ31': 15.35,
#  'FDA04': 11.299999999999999,
#  'FDL21': 15.85,
#  'DRG49': 7.81,
#  'FDR51': 9.035,
#  'FDC39': 7.405,
#  'FDP45': 15.7,
#  'FDC56': 7.72,
#  'FDE59': 12.15,
#  'FDB04': 11.349999999999998,
#  'NCK05': 20.099999999999998,
#  'FDR03': 15.7,
#  'FDQ03': 15.0,
#  'FDC59': 16.7,
#  'DRB13': 6.115,
#  'NCE54': 20.7,
#  'FDP23': 6.709999999999999,
#  'NCL29': 9.695000000000002,
#  'FDM57': 11.65,
#  'FDZ36': 6.035,
#  'FDO46': 9.6,
#  'FDD16': 20.5,
#  'FDZ20': 16.099999999999998,
#  'FDY44': 14.15,
#  'FDW38': 5.325,
#  'FDY33': 14.5,
#  'DRH51': 17.6,
#  'FDI50': 8.42,
#  'FDB60': 9.299999999999999,
#  'FDA20': 6.78,
#  'NCX05': 15.200000000000001,
#  'DRF37': 17.25,
#  'FDJ26': 15.3,
#  'FDZ58': 17.849999999999998,
#  'FDZ50': 12.8,
#  'NCG18': 15.3,
#  'FDH50': 15.0,
#  'DRO35': 13.85,
#  'FDP52': 18.7,
#  'FDC05': 13.1,
#  'NCA41': 16.75,
#  'FDX56': 17.099999999999998,
#  'FDS01': 11.599999999999998,
#  'FDW34': 9.6,
#  'NCP02': 7.105,
#  'FDZ49': 11.0,
#  'NCJ17': 7.68,
#  'FDI53': 8.895,
#  'FDW02': 4.805,
#  ...}

# %% [markdown]
# we created a dictionary in that the unique id of the product contains the average weight of the item.

# %%
def fill_weight_by_id(data):
    
    weight,idd=data[0],data[1]
    if (pd.isnull(weight)): 
        return data_id[idd]
        
    else:
        return weight

# %% [markdown]
# created a function to fill null value with the average weight to that correspondant id.

# %%
data_train['Item_Weight']=data_train[['Item_Weight','Item_Identifier']].apply(fill_weight_by_id,axis=1)

# %% [markdown]
#  fill_weight_by_id function to "Item_Weight" column so that it fill null values with the average weiht with corresponding ids.

# %%
print('NO of null values in the item_weight column of data_test dataset::',data_train.Item_Weight.isna().sum())
# Out:
# NO of null values in the item_weight column of data_test dataset:: 4

# %% [markdown]
# Still there are 4 null values

# %%
np.where(data_train.Item_Weight.isnull())
# Out:
# (array([ 927, 1922, 4187, 5022], dtype=int64),)

# %% [markdown]
# the indices where the item_weight column has null values.

# %%
np.where(data_train.Item_Identifier=='FDN52')
# Out:
# (array([927], dtype=int64),)

# %% [markdown]
# we analyse that the values are still null because the product has no other specific value for weight in it.

# %%
Unique_item_type=data_train.Item_Type.unique().tolist()
data_type={}
for i in Unique_item_type:
    j=data_train.loc[data_train['Item_Type']==i].mean()
    data_type[i]=j['Item_Weight']
data_type
# Out:
# {'Dairy': 13.37990455212926,
#  'Soft Drinks': 11.879775280898892,
#  'Meat': 12.771211764705916,
#  'Fruits and Vegetables': 13.236712662337732,
#  'Household': 13.524780219780286,
#  'Baking Goods': 12.28531684698612,
#  'Snack Foods': 13.031230191826587,
#  'Frozen Foods': 12.782403508771965,
#  'Breakfast': 12.779727272727262,
#  'Health and Hygiene': 13.052326923076956,
#  'Hard Drinks': 11.456238317757009,
#  'Canned': 12.403320493066275,
#  'Breads': 11.297689243027898,
#  'Starchy Foods': 13.841385135135132,
#  'Others': 13.97943786982248,
#  'Seafood': 12.521953125000001}

# %% [markdown]
# we created a dictionary in that the unique type of the item contains the average weight of the item.

# %%
def fill_weight_by_itemType(data):
    
    weight,typ=data[0],data[1]
    if (pd.isnull(weight)): 
        return data_type[typ]
        
    else:
        return weight

# %% [markdown]
# created a function to fill null value with the average weight to that correspondant id.

# %%
data_train['Item_Weight']=data_train[['Item_Weight','Item_Type']].apply(fill_weight_by_itemType,axis=1)

data_train.Item_Weight.isna().sum()
# Out:
# 0

# %% [markdown]
# pplying fill_weight_by_itemType function to "Item_Weight" column so that it fill null values with the average weiht with corresponding types of item.
#
# Now in data_train dataset there are null vales in the Item_weight Column.
#
# Now doing same logic to the data_test dataset for removing null values in the "Item_Wight" column.

# %%
Unique_ids=data_test.Item_Identifier.unique().tolist()
data_id={}
for i in Unique_ids:
    j=data_test.loc[data_test['Item_Identifier']==i].mean()
    data_id[i]=j['Item_Weight']

def fill_weight_by_id(data):
    
    weight,idd=data[0],data[1]
    if (pd.isnull(weight)): 
        return data_id[idd]
        
    else:
        return weight
    
data_test['Item_Weight']=data_test[['Item_Weight','Item_Identifier']].apply(fill_weight_by_id,axis=1)

print('NO. of null values in the item_weight column of data_test dataset used only fill_weight_by_id function::',data_test.Item_Weight.isna().sum())


Unique_item_type=data_test.Item_Type.unique().tolist()
data_type={}
for i in Unique_item_type:
    j=data_test.loc[data_train['Item_Type']==i].mean()
    data_type[i]=j['Item_Weight']

        
    
def fill_weight_by_itemType(data):
    
    weight,typ=data[0],data[1]
    if (pd.isnull(weight)): 
        return data_type[typ]
        
    else:
        return weight
    
data_test['Item_Weight']=data_test[['Item_Weight','Item_Type']].apply(fill_weight_by_itemType,axis=1)
# Out:
# NO. of null values in the item_weight column of data_test dataset used only fill_weight_by_id function:: 20

# %%
print('NO. of null values in the item_weight column of data_test now used  dataset fill_weight_by_itemType function too..::',data_test.Item_Weight.isna().sum())
# Out:
# NO. of null values in the item_weight column of data_test now used  dataset fill_weight_by_itemType function too..:: 0

# %%
data_train.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data_test.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
data_train.Outlet_Size.unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
data_train.Outlet_Size=data_train.Outlet_Size.fillna(data_train.Outlet_Size.mode()[0])

# %% [markdown]
# the test data also has the same features columns . in the dataset. So, i think there is no need to describe them.
#
# Here also we remove null values of Outlet_size of test dataset by the mode.

# %%
data_train.Outlet_Size.unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %% [markdown]
#  we remove null values of Outlet_size of training dataset by the mode.

# %%
data_test.Outlet_Size=data_test.Outlet_Size.fillna(data_test.Outlet_Size.mode()[0])

data_test.Outlet_Size.unique()
# Out:
# array(['Medium', 'Small', 'High'], dtype=object)

# %%
data_test.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
data_train.Outlet_Size.unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %%
data_train.Outlet_Size=data_train.Outlet_Size.fillna(data_train.Outlet_Size.mode()[0])

data_train.Outlet_Size.unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %% [markdown]
# we remove null values of Outlet_size of training dataset by the mode. Doing same with the data_test dataset

# %%
data_test.Outlet_Size=data_test.Outlet_Size.fillna(data_test.Outlet_Size.mode()[0])

data_test.Outlet_Size.unique()
# Out:
# array(['Medium', 'Small', 'High'], dtype=object)

# %%
plt.figure(figsize=(20,60))
sns.catplot(x='Item_Identifier', y='Item_Outlet_Sales',data=data_train)
plt.show()

# %% [markdown]
#  the Item_identifier are distributed within range of 0 to 6500, mostly.

# %%
plt.figure(figsize=(20,60))
sns.catplot(x='Item_Fat_Content', y='Item_Outlet_Sales',data=data_train)
plt.show()

# %% [markdown]
# we can see that the low fat,Low Fat & Lf these are one categorical value while Regular & reg are another categorical value.

# %%
plt.figure(figsize=(60,0.002),clear=True)
sns.catplot(x='Item_Type', y='Item_Outlet_Sales',data=data_train,)
plt.tight_layout()

# %% [markdown]
# All item type are continous with the sale.

# %%
plt.figure(figsize=(20,60))
sns.catplot(x='Outlet_Identifier', y='Item_Outlet_Sales',data=data_train)
plt.show()

# %%
data_train.Outlet_Identifier.unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %% [markdown]
# Outlet_identifier OUT010 and OUT019 there is min sales someow.

# %%
plt.figure(figsize=(20,60))
sns.catplot(x='Outlet_Establishment_Year', y='Item_Outlet_Sales',data=data_train)
plt.show()

# %% [markdown]
# we can see no. of outlet increse there is some decrease in sales. But the older one got the max sales.

# %%
plt.figure(figsize=(20,60))
sns.catplot(x='Outlet_Size', y='Item_Outlet_Sales',data=data_train)
plt.show()

# %% [markdown]
# In medium Outlet_size there is max sale as well not in the high or small type of outlet.

# %%
plt.figure(figsize=(20,60))
sns.catplot(x='Outlet_Location_Type', y='Item_Outlet_Sales',data=data_train)
plt.show()

# %% [markdown]
#  we can there is somehow max sales sales in tier 3.

# %%
plt.figure(figsize=(20,60))
sns.catplot(x='Outlet_Type', y='Item_Outlet_Sales',data=data_train)
plt.show()

# %%
data_train.Outlet_Type.unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %% [markdown]
# we cann see that in Grocery Store the sale is not good.

# %%
cat_dtype=['Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type']

# %%
cat_dtype
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
data_train['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
plt.figure(figsize=(20,40))
graph=1
for col in cat_dtype:
    if graph<11:
        ax=plt.subplot(4,3,graph)
        sns.countplot(data_train[col])
        plt.xlabel(col)
    graph+=1
plt.tight_layout()

# %% [markdown]
# Graph 1: Its tells that the item contains Low fat product more. This column needed to be transform.
#
# Graph2: 'Meat' ,'Baking Goods' has highest sales of these products. and has lowest sale for Breakfast products.
#
# Graph3: this graphs is showing no. of outlet that has their unique ids
#
# Graph4: There are less no. of high Outlet_size
#
# Graph5: Showing no. of Outlet_location_type
#
# Graph6: There are "Super market type 1" outlier are more in markets while others.

# %% [markdown]
# # We have to use encoder techniques to analyse more data.Also for checking Outliers,distribution of Data. to both the Traing & Test Data.

# %%
data_train.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
le=LabelEncoder()
data_train.Item_Identifier=le.fit_transform(data_train.Item_Identifier)

data_train.Item_Fat_Content=data_train.Item_Fat_Content.replace({'Low Fat':0,"LF":0,'low fat':0,"reg":1,"Regular":1})

data_train.Item_Type=le.fit_transform(data_train.Item_Type)

data_train.Outlet_Identifier=le.fit_transform(data_train.Outlet_Identifier)

data_train.Outlet_Type=le.fit_transform(data_train.Outlet_Type)

# %% [markdown]
# uSED lABEL eNCODER TO TRANSFORM THE CATEGORICAL dATA INTO INTGER DATA TYPE iN tRAIN DATAsET .

# %%
data_test.Item_Fat_Content=data_test.Item_Fat_Content.replace({'Low Fat':0,"LF":0,'low fat':0,"reg":1,"Regular":1})

data_test.Item_Identifier=le.fit_transform(data_test.Item_Identifier)

data_test.Item_Type=le.fit_transform(data_test.Item_Type)

data_test.Outlet_Identifier=le.fit_transform(data_test.Outlet_Identifier)

data_test.Outlet_Type=le.fit_transform(data_test.Outlet_Type)

# %% [markdown]
# uSED lABEL eNCODER TO TRANSFORM THE CATEGORICAL dATA INTO INTGER DATA TYPE iN tEST DATAsET .

# %%
data_train.Outlet_Size.unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %% [markdown]
# sHOWING tHE UNIQUE VALUE oF tHE oUTLET_sIZE COLUMN.

# %%
data_train.Outlet_Location_Type.unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %% [markdown]
# sHOWING tHE UNIQUE VALUE oF tHE oUTLET_lOCATION_tYPE COLUMN.

# %%
Oe=OrdinalEncoder(categories=[['Small','Medium','High'],['Tier 1','Tier 2','Tier 3']])

data_train[['Outlet_Size','Outlet_Location_Type']]=Oe.fit_transform(data_train[['Outlet_Size','Outlet_Location_Type']])

data_test[['Outlet_Size','Outlet_Location_Type']]=Oe.fit_transform(data_test[['Outlet_Size','Outlet_Location_Type']])

# %% [markdown]
# Used Ordinal Encoder as the the size & location type of outlet is in order. So, we need to transform it in an order.

# %%
data_test.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103       20.750                 0         0.007565         13
# 1             1067        8.300                 1         0.038428          4
# 2             1406       14.600                 0         0.099575         11
# 3              809        7.315                 0         0.015388         13
# 4             1184       13.600                 1         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999          1.0
# 1   87.3198                  2                       2007          1.0
# 2  241.7538                  0                       1998          1.0
# 3  155.0340                  2                       2007          1.0
# 4  234.2300                  5                       1985          1.0
#
#    Outlet_Location_Type  Outlet_Type
# 0                   0.0            1
# 1                   1.0            1
# 2                   2.0            0
# 3                   1.0            1
# 4                   2.0            3

# %% [markdown]
# After removing nan, transormed training dataset is represented with top 5 records.

# %%
data_train.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999          1.0
# 1   48.2692                  3                       2009          1.0
# 2  141.6180                  9                       1999          1.0
# 3  182.0950                  0                       1998          1.0
# 4   53.8614                  1                       1987          2.0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                   0.0            1          3735.1380
# 1                   2.0            2           443.4228
# 2                   0.0            1          2097.2700
# 3                   2.0            0           732.3800
# 4                   2.0            1           994.7052

# %% [markdown]
# After removing nan, transormed testing dataset is represented with top 5 records.

# %%
plt.figure(figsize=(20,50))
graph=1
for col in data_train:
    if graph<12:
        ax=plt.subplot(4,3,graph)
        sns.scatterplot(x=data_train[col],y=data_train.Item_Outlet_Sales)
        plt.xlabel(col)
    graph+=1
plt.tight_layout()

# %% [markdown]
# Graph1: It seems to be like that the unique id of item is normally distributed and contains some outliers.And also seems to be like no relation with Item_Outlet_sales.
#
# Graph2: It seems to be like that the weight of item is normally distributed and contains some outliers.And also seems to be like no relation with Item_Outlet_sales.
#
# Graph3: It seems to be like that the fat content of item is normally distributed and contains some outliers.And also seems to be like no relation with Item_Outlet_sales.
#
# Graph4: Its seems like leess the visibility more the sales of item.
#
# Graph5: the type of items are equally distributed
#
# Graph6: Higher the Mrp highe the sales o the item.
#
# Graph7: There are some id outlet that has low sales and are continous.
#
# Graph8: As the the outlet are establishing there is somehow very less decrease in the sales. thatmeans the no. outlet increasing there is very less decrease of sale.
#
# Graph9: the medium size outlat sizes are high.
#
# Graph10: lower the location higher the sales.
#
# Graph 11: the outlet_type 0 has minimium sales while other types in it.

# %%
plt.figure(figsize=(20,50))
graph=1
for col in data_train:
    if graph<12:
        ax=plt.subplot(4,3,graph)
        sns.distplot(data_train[col])
        plt.xlabel(col)
    graph+=1
plt.tight_layout()

# %% [markdown]
# Graph1: It seems to be like that the unique id of item is normally distributed .
#
# Graph2: It seems to be like that the weight of item is normally distributed.
#
# Graph3: It seems to be like that the fat content of item is not normally distributed.
#
# Graph4: Its seems like the visibility skewed.
#
# Graph5: the type of items are equally distributed
#
# Graph6: It seems to be like that the MRP of item is normally distributed.
#
# Graph7: It seems to be like that the ids of outlet are normally distributed..
#
# Graph8: It seems to be like that the establishment of outlet is normally distributed.
#
# Graph9: It seems to be like that the size of outlet is not normally distributed.
#
# Graph10: It seems to be like that the location type of outlet is not normally distributed.
#
# Graph 11: It seems to be like that the type of outlet is not normally distributed.

# %%
data_train.skew()
# Out:
# Item_Identifier             -0.008877
# Item_Weight                  0.070333
# Item_Fat_Content             0.616705
# Item_Visibility              1.167091
# Item_Type                    0.101655
# Item_MRP                     0.127202
# Outlet_Identifier           -0.059861
# Outlet_Establishment_Year   -0.396641
# Outlet_Size                  0.087072
# Outlet_Location_Type        -0.209093
# Outlet_Type                  0.927438
# Item_Outlet_Sales            1.177531
# dtype: float64

# %% [markdown]
# 'Item_Fat_Content','Item_Visibility'& 'Outlet_Type' are not in range of -0.5 to 0.5. So they are skewed columns. while others are in range so, there distibution is normal.

# %%
plt.figure(figsize=(20,50))
graph=1
for col in data_test:
    if graph<12:
        ax=plt.subplot(4,3,graph)
        sns.distplot(data_test[col])
        plt.xlabel(col)
    graph+=1
plt.tight_layout()

# %% [markdown]
# Graph1: It seems to be like that the unique id of item is normally distributed .
#
# Graph2: It seems to be like that the weight of item is normally distributed.
#
# Graph3: It seems to be like that the fat content of item is not normally distributed.
#
# Graph4: Its seems like the visibility skewed.
#
# Graph5: the type of items are equally distributed
#
# Graph6: It seems to be like that the MRP of item is normally distributed.
#
# Graph7: It seems to be like that the ids of outlet are normally distributed..
#
# Graph8: It seems to be like that the establishment of outlet is normally distributed.
#
# Graph9: It seems to be like that the size of outlet is not normally distributed.
#
# Graph10: It seems to be like that the location type of outlet is not normally distributed.
#
# Graph 11: It seems to be like that the type of outlet is not normally distributed.

# %%
data_test.skew()
# Out:
# Item_Identifier             -0.000020
# Item_Weight                  0.144712
# Item_Fat_Content             0.609223
# Item_Visibility              1.238312
# Item_Type                    0.096486
# Item_MRP                     0.136182
# Outlet_Identifier           -0.060209
# Outlet_Establishment_Year   -0.396306
# Outlet_Size                  0.087108
# Outlet_Location_Type        -0.209049
# Outlet_Type                  0.927446
# dtype: float64

# %% [markdown]
# Item_Fat_Content','Item_Visibility'& 'Outlet_Type' are not in range of -0.5 to 0.5. So they are skewed columns. while others are in range so, there distibution is normal.

# %%
plt.figure(figsize=(20,10))
graph=1
for col in data_train:
    if graph<12:
        ax=plt.subplot(4,3,graph)
        sns.boxplot(data_train[col],orient='v')
        plt.xlabel(col)
    graph+=1
plt.tight_layout()

# %% [markdown]
# In Graph 4 the item_visibility & graph 11 type of outlet has outliers while in all other graphs there are no outliers exists.

# %%
plt.figure(figsize=(20,10))
graph=1
for col in data_test:
    if graph<12:
        ax=plt.subplot(4,3,graph)
        sns.boxplot(data_test[col],orient='v')
        plt.xlabel(col)
    graph+=1
plt.tight_layout()

# %% [markdown]
# In Graph 4 the item_visibility & graph 11 type of outlet has outliers while in all other graphs there are no outliers exists.

# %%
plt.figure(figsize=(40,40))
sns.heatmap(data_train.corr().abs(),annot=True,annot_kws={"size":25},linewidths=True)
plt.show()

# %% [markdown]
# There 72% of multicolinearity exists between the columns Outlet_Location_type and Outlet_identifier.
#
# there 61% of multicolinearity exists between the columns Outlet_Size and Outlet_Location_Type.
#
# the Item_Outlet_sale is dependent on Item_MRP column with 57% helpful, Outlet_Type with 40%, and 13% with item_visibility and 16% outlet_idetifier

# %%
data_train.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# # Hypothesis testing & p_value

# %% [markdown]
# Ho: No relationship exists between target variable(i.e. Outlet_sales) & features .
#
# H1: reltionship exists between target variable(i.e. Outlet_sales) & features.

# %%
lm=smf.ols(formula='Item_Outlet_Sales~Item_Identifier+Item_Weight+Item_Fat_Content+Item_Visibility+Item_Type+Item_MRP+Outlet_Identifier+Outlet_Establishment_Year+Outlet_Size+Outlet_Location_Type+Outlet_Type',data=data_train).fit()

lm.pvalues
# Out:
# Intercept                     6.126621e-01
# Item_Identifier               8.116726e-01
# Item_Weight                   8.892614e-01
# Item_Fat_Content              4.478061e-02
# Item_Visibility               7.603491e-08
# Item_Type                     7.784065e-01
# Item_MRP                      0.000000e+00
# Outlet_Identifier             1.309117e-10
# Outlet_Establishment_Year     9.187580e-01
# Outlet_Size                   5.649921e-33
# Outlet_Location_Type          8.372303e-09
# Outlet_Type                  9.878056e-229
# dtype: float64

# %% [markdown]
#  we getting the pValues of each column:
#
# So, from above information we can conclude that the column that are greater than 0.05 are ready to accepts the null hypothesis.
#
# The columns that are Item_Identifier,Item_Weight,Item_Type,Outlet_Establishment_Year  are the columns thats pvalues are greater than 0.05 which means these columns are ready to accepts the null hypothesis.
#
# While other columns rejects to accepts the null hypothesis as their pvalues is smaller than 0.05.

# %%
data_train.shape
# Out:
# (8523, 12)

# %% [markdown]
# there are 8523 no. of records before cleaning.

# %% [markdown]
# # DATA Cleaning

# %%
data_train.describe()
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# count      8523.000000  8523.000000       8523.000000      8523.000000
# mean        779.714889    12.875418          0.352693         0.066132
# std         449.222377     4.645016          0.477836         0.051598
# min           0.000000     4.555000          0.000000         0.000000
# 25%         395.500000     8.785000          0.000000         0.026989
# 50%         783.000000    12.650000          0.000000         0.053931
# 75%        1167.000000    16.850000          1.000000         0.094585
# max        1558.000000    21.350000          1.000000         0.328391
#
#          Item_Type     Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# count  8523.000000  8523.000000        8523.000000                8523.000000
# mean      7.226681   140.992782           4.722281                1997.831867
# std       4.209990    62.275067           2.837201                   8.371760
# min       0.000000    31.290000           0.000000                1985.000000
# 25%       4.000000    93.826500           2.000000                1987.000000
# 50%       6.000000   143.012800           5.000000                1999.000000
# 75%      10.000000   185.643700           7.000000                2004.000000
# max      15.000000   266.888400           9.000000                2009.000000
#
#        Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# count  8523.000000           8523.000000  8523.000000        8523.000000
# mean      0.829168              1.112871     1.201220        2181.288914
# std       0.600327              0.812757     0.796459        1706.499616
# min       0.000000              0.000000     0.000000          33.290000
# 25%       0.000000              0.000000     1.000000         834.247400
# 50%       1.000000              1.000000     1.000000        1794.331000
# 75%       1.000000              2.000000     1.000000        3101.296400
# max       2.000000              2.000000     3.000000       13086.964800

# %% [markdown]
# IN the column Item_fat_content has standard deviation greter then its mean value. this applies that the column is not normaly distributed. and in column Outlet_Type 2 type of outet are not such distributed in that column.

# %%
data_test.describe()
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# count      5681.000000  5681.000000       5681.000000      5681.000000
# mean        773.386376    12.676136          0.354339         0.065684
# std         445.525926     4.649378          0.478355         0.051252
# min           0.000000     4.555000          0.000000         0.000000
# 25%         382.000000     8.630000          0.000000         0.027047
# 50%         771.000000    12.350000          0.000000         0.054154
# 75%        1160.000000    16.700000          1.000000         0.093463
# max        1542.000000    21.350000          1.000000         0.323637
#
#          Item_Type     Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# count  5681.000000  5681.000000        5681.000000                5681.000000
# mean      7.233410   141.023273           4.722760                1997.828903
# std       4.219057    61.809091           2.837201                   8.372256
# min       0.000000    31.990000           0.000000                1985.000000
# 25%       4.000000    94.412000           2.000000                1987.000000
# 50%       6.000000   141.415400           5.000000                1999.000000
# 75%      10.000000   186.026600           7.000000                2004.000000
# max      15.000000   266.588400           9.000000                2009.000000
#
#        Outlet_Size  Outlet_Location_Type  Outlet_Type
# count  5681.000000           5681.000000  5681.000000
# mean      0.829079              1.112832     1.201373
# std       0.600328              0.812824     0.796740
# min       0.000000              0.000000     0.000000
# 25%       0.000000              0.000000     1.000000
# 50%       1.000000              1.000000     1.000000
# 75%       1.000000              2.000000     1.000000
# max       2.000000              2.000000     3.000000

# %% [markdown]
# IN the column Item_fat_content has standard deviation greter then its mean value. this applies that the column is not normaly distributed. and in column Outlet_Type 2 type of outet are not such distributed in that column.

# %% [markdown]
# REmoving Duplicates.

# %%
data_train.drop_duplicates(inplace=True)

# %%
data_test.drop_duplicates(inplace=True)

# %%
data_train.shape
# Out:
# (8523, 12)

# %%
data_test.shape
# Out:
# (5681, 11)

# %% [markdown]
# NO, duplicates in training & test daataset.

# %% [markdown]
# Removing outliers

# %%
zs=zscore(data_train[["Item_Visibility","Outlet_Type"]])
filtered=(np.abs(zs)<3).all(axis=1)
data_train=data_train[filtered]

# %% [markdown]
# Removed outliers for the type of outlet and visibility of item from training dataset..

# %%
    zs=zscore(data_test[["Item_Visibility","Outlet_Type"]])
filtered=(np.abs(zs)<3).all(axis=1)
data_test=data_test[filtered]

# %% [markdown]
# Removed outliers for the type of outlet and visibility of item from test dataset

# %%
data_train.shape
# Out:
# (8428, 12)

# %%
data_test.shape
# Out:
# (5600, 11)

# %% [markdown]
# # Checking for outliers using boxplot for both training &test dataset

# %%
plt.figure(figsize=(20,10))
graph=1
for col in data_test:
    if graph<12:
        ax=plt.subplot(4,3,graph)
        sns.boxplot(data_train[col],orient='v')
        plt.xlabel(col)
    graph+=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
graph=1
for col in data_test:
    if graph<12:
        ax=plt.subplot(4,3,graph)
        sns.boxplot(data_test[col],orient='v')
        plt.xlabel(col)
    graph+=1
plt.tight_layout()

# %% [markdown]
# # Normailizing the distribution

# %%
features=data_train.columns.tolist()
f=features[:-1]

# %%
scalar=PowerTransformer(method='yeo-johnson')
data_train[f]=scalar.fit_transform(data_train[f].values)
data_train
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           -1.460187    -0.734583         -0.736710        -1.142270
# 1           -2.093558    -1.598850          1.357386        -1.032913
# 2           -0.153960     0.990250         -0.736710        -1.117874
# 3            0.772354     1.306840          1.357386        -1.734798
# 4            1.096612    -0.823160         -0.736710        -1.734798
# ...               ...          ...               ...              ...
# 8518        -0.843731    -1.343314         -0.736710         0.033409
# 8519         0.337530    -0.957231          1.357386        -0.212619
# 8520         1.204212    -0.432697         -0.736710        -0.537754
# 8521        -0.112547    -1.253027          1.357386         1.538309
# 8522        -1.861795     0.463160         -0.736710        -0.268203
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0     -0.713260  1.622782           1.423152                   0.039060
# 1      1.505750 -1.595589          -0.561913                   1.453989
# 2      0.684503  0.081596           1.423152                   0.039060
# 3     -0.216081  0.690021          -1.820107                  -0.085435
# 4      0.468305 -1.476469          -1.356875                  -1.281792
# ...         ...       ...                ...                        ...
# 8518   1.306137  1.147914          -1.356875                  -1.281792
# 8519  -1.924399 -0.462744           0.802337                   0.430122
# 8520   0.246688 -0.867711           0.479291                   0.706147
# 8521   1.306137 -0.548634          -0.561913                   1.453989
# 8522   1.505750 -1.047138           1.116562                  -0.207109
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0        0.308401             -1.380097    -0.145161          3735.1380
# 1        0.308401              1.089709     1.034704           443.4228
# 2        0.308401             -1.380097    -0.145161          2097.2700
# 3        0.308401              1.089709    -1.974400           732.3800
# 4        1.856328              1.089709    -0.145161           994.7052
# ...           ...                   ...          ...                ...
# 8518     1.856328              1.089709    -0.145161          2778.3834
# 8519     0.308401             -0.137247    -0.145161           549.2850
# 8520    -1.422593             -0.137247    -0.145161          1193.1136
# 8521     0.308401              1.089709     1.034704          1845.5976
# 8522    -1.422593             -1.380097    -0.145161           765.6700
#
# [8428 rows x 12 columns]

# %%
plt.figure(figsize=(20,50))
graph=1
for col in data_train:
    if graph<12:
        ax=plt.subplot(4,3,graph)
        sns.distplot(data_train[col])
        plt.xlabel(col)
    graph+=1
plt.tight_layout()

# %%
data_train.skew()
# Out:
# Item_Identifier             -0.293573
# Item_Weight                 -0.089666
# Item_Fat_Content             0.620786
# Item_Visibility              0.115444
# Item_Type                   -0.164518
# Item_MRP                    -0.114976
# Outlet_Identifier           -0.214763
# Outlet_Establishment_Year   -0.213023
# Outlet_Size                 -0.072301
# Outlet_Location_Type        -0.221268
# Outlet_Type                  0.009297
# Item_Outlet_Sales            1.173070
# dtype: float64

# %% [markdown]
# Now, all features are distribued normaslly.
#
#
#
#
# Same techniques we apply for test dataset.

# %%
scalar=PowerTransformer(method='yeo-johnson')
data_test[f]=scalar.fit_transform(data_test.values)
data_test
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0            0.755237     1.588963         -0.738413        -1.453107
# 1            0.686438    -0.927622          1.354256        -0.440632
# 2            1.310999     0.478888         -0.738413         0.926222
# 3            0.171593    -1.188068         -0.738413        -1.170062
# 4            0.907712     0.278319          1.354256         1.229130
# ...               ...          ...               ...              ...
# 5676        -1.224280    -0.392820          1.354256        -1.236731
# 5677        -1.009519    -1.111158          1.354256         1.556046
# 5678         1.321631    -0.509411         -0.738413         0.427676
# 5679        -0.473750     0.615393          1.354256        -1.746075
# 5680         0.531093    -0.628749          1.354256         1.012775
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0      1.299513 -0.474785           1.422378                   0.037205
# 1     -0.713854 -0.838728          -0.949875                   1.142704
# 2      0.889786  1.525696          -1.824752                  -0.087281
# 3      1.299513  0.288663          -0.949875                   1.142704
# 4     -0.713854  1.424586           0.141725                  -1.470222
# ...         ...       ...                ...                        ...
# 5676   1.299513  0.075140           1.114843                  -0.208944
# 5677   1.695238  0.502272          -0.567093                   1.452134
# 5678   0.242054 -0.290777           0.799736                   0.428247
# 5679  -0.978901  1.156208          -0.949875                   1.142704
# 5680  -0.978901 -0.978466           0.799736                   0.428247
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0        0.307006             -1.380965    -0.151382
# 1        0.307006             -0.137311    -0.151382
# 2        0.307006              1.090644    -1.991879
# 3        0.307006             -0.137311    -0.151382
# 4        0.307006              1.090644     1.925057
# ...           ...                   ...          ...
# 5676    -1.423594             -1.380965    -0.151382
# 5677     0.307006              1.090644     1.032759
# 5678     0.307006             -0.137311    -0.151382
# 5679     0.307006             -0.137311    -0.151382
# 5680     0.307006             -0.137311    -0.151382
#
# [5600 rows x 11 columns]

# %%
plt.figure(figsize=(20,50))
graph=1
for col in data_test:
    if graph<12:
        ax=plt.subplot(4,3,graph)
        sns.distplot(data_test[col])
        plt.xlabel(col)
    graph+=1
plt.tight_layout()

# %% [markdown]
# we do Power Transformer technique so that we normal distribution.

# %%
data_test.skew()
# Out:
# Item_Identifier             -0.287266
# Item_Weight                 -0.070861
# Item_Fat_Content             0.616007
# Item_Visibility              0.105676
# Item_Type                   -0.169452
# Item_MRP                    -0.111505
# Outlet_Identifier           -0.214813
# Outlet_Establishment_Year   -0.215341
# Outlet_Size                 -0.072193
# Outlet_Location_Type        -0.220882
# Outlet_Type                  0.009585
# dtype: float64

# %% [markdown]
# all features are distribued normaslly.

# %%
data_test.head(2)
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0         0.755237     1.588963         -0.738413        -1.453107   1.299513
# 1         0.686438    -0.927622          1.354256        -0.440632  -0.713854
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0 -0.474785           1.422378                   0.037205     0.307006
# 1 -0.838728          -0.949875                   1.142704     0.307006
#
#    Outlet_Location_Type  Outlet_Type
# 0             -1.380965    -0.151382
# 1             -0.137311    -0.151382

# %% [markdown]
# #    Removing column which accepts null hypothesis.

# %%
X=data_train.drop(columns='Item_Outlet_Sales')
Y=data_train['Item_Outlet_Sales']

# %% [markdown]
# splitting data into fetures & labels.

# %% [markdown]
# Here X is our features & Y is our label.

# %%
X.corrwith(Y)
# Out:
# Item_Identifier              0.004754
# Item_Weight                  0.012154
# Item_Fat_Content             0.021202
# Item_Visibility             -0.076931
# Item_Type                    0.019329
# Item_MRP                     0.572278
# Outlet_Identifier            0.163777
# Outlet_Establishment_Year   -0.053740
# Outlet_Size                  0.081393
# Outlet_Location_Type         0.087694
# Outlet_Type                  0.419608
# dtype: float64

# %% [markdown]
# column that has less impact on prediction of sales that are Item_Identifier,Item_Weight,Item_Fat_Content,Item_Type

# %%
X.drop(columns=['Item_Identifier','Item_Weight','Item_Fat_Content','Item_Type'],inplace=True,axis=1)

# %%
X.shape
# Out:
# (8428, 7)

# %% [markdown]
# dropped columns now the shape has changed.

# %%
data_test.drop(columns=['Item_Identifier','Item_Weight','Item_Fat_Content','Item_Type'],inplace=True,axis=1)

# %%
data_test.shape
# Out:
# (5600, 7)

# %% [markdown]
# these features also should be dropped because these has no such impact to the label.

# %%
scalar=StandardScaler()
X_scaled=scalar.fit_transform(X)

# %%
scalar=StandardScaler()
Xtt_scaled=scalar.fit_transform(data_test)

# %% [markdown]
# Standarized the features .

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(X_scaled,i) for i in range(X_scaled.shape[1])]
vif['Features']=X.columns

# %%
vif
# Out:
#         vif                   Features
# 0  1.022728            Item_Visibility
# 1  1.000206                   Item_MRP
# 2  4.703737          Outlet_Identifier
# 3  1.042913  Outlet_Establishment_Year
# 4  1.712762                Outlet_Size
# 5  5.469949       Outlet_Location_Type
# 6  2.768149                Outlet_Type

# %% [markdown]
# From above information we get to know that the column Outlet_Location_type has valu 5.47 i.e. greater than 5. So, we can drop this value becoz this it multi-colinearity problem

# %%
X.drop('Outlet_Location_Type',axis=1,inplace=True)

# %%
X.shape
# Out:
# (8428, 6)

# %% [markdown]
# Same we do to test data

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(Xtt_scaled,i) for i in range(Xtt_scaled.shape[1])]
vif['Features']=data_test.columns
vif
# Out:
#         vif                   Features
# 0  1.019731            Item_Visibility
# 1  1.000397                   Item_MRP
# 2  4.685115          Outlet_Identifier
# 3  1.046481  Outlet_Establishment_Year
# 4  1.713040                Outlet_Size
# 5  5.476445       Outlet_Location_Type
# 6  2.751811                Outlet_Type

# %% [markdown]
# From above information we get to know that the column Outlet_Location_type has valu 5.47 i.e. greater than 5. So, we can drop this value becoz this it multi-colinearity problem

# %%
data_test.drop('Outlet_Location_Type',axis=1,inplace=True)

# %%
data_test.shape
# Out:
# (5600, 6)

# %% [markdown]
# # Data loss

# %%
print(f"The Trained Dataset has lost the records in percentage after Cleaning:: {((8523-8428)/8523)*100}%")
# Out:
# The Trained Dataset has lost the records in percentage after Cleaning:: 1.1146309984747156%

# %%
print(f"The Test Dataset has lost the records in percentage after Cleaning:: {((5681-5600)/5681)*100}%")
# Out:
# The Test Dataset has lost the records in percentage after Cleaning:: 1.425805315965499%

# %% [markdown]
# # Model Deployment

# %%
max_accuracy=0
for i in range(1,150):
    X_train,X_test,Y_train,Y_test=train_test_split(X_scaled,Y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    lr.fit(X_train,Y_train)
    Y_pred=lr.predict(X_test)
    accuracy=r2_score(Y_test,Y_pred)*100
    if accuracy>max_accuracy:
        max_accuracy=accuracy
        rs=i
print(f"The highest accuracy is {max_accuracy} at random state {rs}")
# Out:
# The highest accuracy is 55.88198039380388 at random state 115

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_scaled,Y,test_size=0.2,random_state=rs)

# %% [markdown]
#  we split the training dataset & test dataset at random state rs i.e. 115 where we get the high accuracy

# %%
Linear=LinearRegression()
DecisionTree=DecisionTreeRegressor()
knn=KNeighborsRegressor()
RandomForest=RandomForestRegressor()
AdaBoost=AdaBoostRegressor()
Bagging=BaggingRegressor()

# %%
algo=[Linear,DecisionTree,RandomForest,knn,AdaBoost,Bagging]
acc_models={}
for model in algo:
    model.fit(X_train,Y_train)
    Y_pred=model.predict(X_test)
    print("-"*60)
    acc_models[model]=round(r2_score(Y_test,Y_pred)*100,1)
    print(f"The model {model} has:: \n\t Accuracy :: {round(r2_score(Y_test,Y_pred)*100,1)}% \n\t Mean Absolute Error is :: {mean_absolute_error(Y_test,Y_pred)} \n\t Mean Squared Error is :: {mean_squared_error(Y_test,Y_pred)} \n\t Root Mean Squared Error is :: {np.sqrt(mean_squared_error(Y_test,Y_pred))}")
    print("-"*60)
    print("\n")
# Out:
# ------------------------------------------------------------
# The model LinearRegression() has::
# 	 Accuracy :: 55.9%
# 	 Mean Absolute Error is :: 880.2010461472506
# 	 Mean Squared Error is :: 1387857.8461036219
# 	 Root Mean Squared Error is :: 1178.0737863578927
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# The model DecisionTreeRegressor() has::
# 	 Accuracy :: 31.5%
# 	 Mean Absolute Error is :: 1017.5189199288258
# 	 Mean Squared Error is :: 2154521.809143676
# 	 Root Mean Squared Error is :: 1467.8289441020286
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# The model RandomForestRegressor() has::
# 	 Accuracy :: 58.1%
# 	 Mean Absolute Error is :: 798.7068380403322
# 	 Mean Squared Error is :: 1316997.231240958
# 	 Root Mean Squared Error is :: 1147.6049979156408
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# The model KNeighborsRegressor() has::
# 	 Accuracy :: 56.5%
# 	 Mean Absolute Error is :: 820.7966604033214
# 	 Mean Squared Error is :: 1369903.132174849
# 	 Root Mean Squared Error is :: 1170.4286104563785
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# The model AdaBoostRegressor() has::
# 	 Accuracy :: 52.6%
# 	 Mean Absolute Error is :: 951.0290397387466
# 	 Mean Squared Error is :: 1492046.54767327
# 	 Root Mean Squared Error is :: 1221.4935725059179
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# The model BaggingRegressor() has::
# 	 Accuracy :: 56.2%
# 	 Mean Absolute Error is :: 819.6519266903915
# 	 Mean Squared Error is :: 1378170.677730481
# 	 Root Mean Squared Error is :: 1173.9551429805488
# ------------------------------------------------------------

# %%
acc_models
# Out:
# {LinearRegression(): 55.9,
#  DecisionTreeRegressor(): 31.5,
#  RandomForestRegressor(): 58.1,
#  KNeighborsRegressor(): 56.5,
#  AdaBoostRegressor(): 52.6,
#  BaggingRegressor(): 56.2}

# %% [markdown]
#  we get the maximum r2-score of each model

# %% [markdown]
# # Crooss-Vaidation of the model

# %%
CVmodel={}

for model in algo:
    CVscore_={}
    print(f"\n{model}")
    print("-"*25)
    print("\n")
    for i in range(2,10):
        cvS=cross_val_score(model,X_scaled,Y,cv=i)
        CVscore_[i]=cvS.mean()
        print(f"Mean CV Score of model {model}:: {cvS.mean()} at k-fold::{i}\n")
    CVdata=pd.DataFrame(CVscore_,index=[""])
    CVmodel[str(model)]=CVdata.max(axis=1).tolist()
# Out:
# LinearRegression()
# -------------------------
#
#
# Mean CV Score of model LinearRegression():: 0.5195613356158699 at k-fold::2
#
# Mean CV Score of model LinearRegression():: 0.5190328063609789 at k-fold::3
#
# Mean CV Score of model LinearRegression():: 0.5180793211766609 at k-fold::4
#
# Mean CV Score of model LinearRegression():: 0.5187317026775052 at k-fold::5
#
# Mean CV Score of model LinearRegression():: 0.5189041583552314 at k-fold::6
#
# Mean CV Score of model LinearRegression():: 0.5191882522449176 at k-fold::7
#
# Mean CV Score of model LinearRegression():: 0.5186428749867475 at k-fold::8
#
# Mean CV Score of model LinearRegression():: 0.5188069461654009 at k-fold::9
#
#
# DecisionTreeRegressor()
# -------------------------
#
#
# Mean CV Score of model DecisionTreeRegressor():: 0.1919783718786075 at k-fold::2
#
# Mean CV Score of model DecisionTreeRegressor():: 0.18593358715285155 at k-fold::3
#
# Mean CV Score of model DecisionTreeRegressor():: 0.16680710595790837 at k-fold::4
#
# Mean CV Score of model DecisionTreeRegressor():: 0.18188589306731168 at k-fold::5
#
# Mean CV Score of model DecisionTreeRegressor():: 0.18440442321737646 at k-fold::6
#
# Mean CV Score of model DecisionTreeRegressor():: 0.18536953598288528 at k-fold::7
#
# Mean CV Score of model DecisionTreeRegressor():: 0.17737958656565003 at k-fold::8
#
# Mean CV Score of model DecisionTreeRegressor():: 0.18138680511149752 at k-fold::9
#
#
# RandomForestRegressor()
# -------------------------
#
#
# Mean CV Score of model RandomForestRegressor():: 0.5388610226337079 at k-fold::2
#
# Mean CV Score of model RandomForestRegressor():: 0.5406194194971516 at k-fold::3
#
# Mean CV Score of model RandomForestRegressor():: 0.5386748861007201 at k-fold::4
#
# Mean CV Score of model RandomForestRegressor():: 0.5419455080337917 at k-fold::5
#
# Mean CV Score of model RandomForestRegressor():: 0.5432425954884811 at k-fold::6
#
# Mean CV Score of model RandomForestRegressor():: 0.5430376561607212 at k-fold::7
#
# Mean CV Score of model RandomForestRegressor():: 0.5411547134121694 at k-fold::8
#
# Mean CV Score of model RandomForestRegressor():: 0.5410625341201203 at k-fold::9
#
#
# KNeighborsRegressor()
# -------------------------
#
#
# Mean CV Score of model KNeighborsRegressor():: 0.5215137149754223 at k-fold::2
#
# Mean CV Score of model KNeighborsRegressor():: 0.5256958948112967 at k-fold::3
#
# Mean CV Score of model KNeighborsRegressor():: 0.5245135657662343 at k-fold::4
#
# Mean CV Score of model KNeighborsRegressor():: 0.5257547857148545 at k-fold::5
#
# Mean CV Score of model KNeighborsRegressor():: 0.5262789207007591 at k-fold::6
#
# Mean CV Score of model KNeighborsRegressor():: 0.5283943159761092 at k-fold::7
#
# Mean CV Score of model KNeighborsRegressor():: 0.5267840903139557 at k-fold::8
#
# Mean CV Score of model KNeighborsRegressor():: 0.5294499041483308 at k-fold::9
#
#
# AdaBoostRegressor()
# -------------------------
#
#
# Mean CV Score of model AdaBoostRegressor():: 0.4986665214510993 at k-fold::2
#
# Mean CV Score of model AdaBoostRegressor():: 0.45816562399988764 at k-fold::3
#
# Mean CV Score of model AdaBoostRegressor():: 0.49993225698567145 at k-fold::4
#
# Mean CV Score of model AdaBoostRegressor():: 0.487517600335754 at k-fold::5
#
# Mean CV Score of model AdaBoostRegressor():: 0.5027290021737797 at k-fold::6
#
# Mean CV Score of model AdaBoostRegressor():: 0.4879129244676998 at k-fold::7
#
# Mean CV Score of model AdaBoostRegressor():: 0.4905095704597263 at k-fold::8
#
# Mean CV Score of model AdaBoostRegressor():: 0.48836038879117294 at k-fold::9
#
#
# BaggingRegressor()
# -------------------------
#
#
# Mean CV Score of model BaggingRegressor():: 0.5157029010020532 at k-fold::2
#
# Mean CV Score of model BaggingRegressor():: 0.5071802503688697 at k-fold::3
#
# Mean CV Score of model BaggingRegressor():: 0.5111969769848129 at k-fold::4
#
# Mean CV Score of model BaggingRegressor():: 0.5103124437706728 at k-fold::5
#
# Mean CV Score of model BaggingRegressor():: 0.5114498553845203 at k-fold::6
#
# Mean CV Score of model BaggingRegressor():: 0.5109199052668257 at k-fold::7
#
# Mean CV Score of model BaggingRegressor():: 0.5008249625173191 at k-fold::8
#
# Mean CV Score of model BaggingRegressor():: 0.507793190262614 at k-fold::9

# %%
CVmodel
# Out:
# {'LinearRegression()': [0.5195613356158699],
#  'DecisionTreeRegressor()': [0.1919783718786075],
#  'RandomForestRegressor()': [0.5432425954884811],
#  'KNeighborsRegressor()': [0.5294499041483308],
#  'AdaBoostRegressor()': [0.5027290021737797],
#  'BaggingRegressor()': [0.5157029010020532]}

# %% [markdown]
#  we can see the maximun CV score of each model

# %%
acc_value=list(acc_models.values ( ))

m=list(CVmodel.keys())

print("The least difference between the r2-score and CV score of each model is::\n")
for i in range(6):
    print(f"{m[i]}::{round(np.abs(CVmodel[m[i]][0]*100-acc_value[i]),2)}")
# Out:
# The least difference between the r2-score and CV score of each model is::
#
# LinearRegression()::3.94
# DecisionTreeRegressor()::12.3
# RandomForestRegressor()::3.78
# KNeighborsRegressor()::3.56
# AdaBoostRegressor()::2.33
# BaggingRegressor()::4.63

# %% [markdown]
# model KNeighborsRegressor we get the least value i.e. the difference between the r2-score and cvScore of this model is 3.56. So, knn is the best model to use for this problem.

# %%
knn.fit(X_train,Y_train)
sns.regplot(Y_test,Y_pred)
plt.xlabel("Actual Test Data")
plt.ylabel("Predicted Data")
plt.tight_layout()

# %% [markdown]
# we can see that the points are now much closer than the earlier KNeighborsRegresso model with default parameter to the best fit line, Its due to decrease in mean absolute error, mean Squared Error,& Root mean squared error.

# %% [markdown]
# And incrsed in the Accuracy

# %% [markdown]
# # Saving model

# %%
data_test.head()
# Out:
#    Item_Visibility  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0        -1.453107 -0.474785           1.422378                   0.037205
# 1        -0.440632 -0.838728          -0.949875                   1.142704
# 2         0.926222  1.525696          -1.824752                  -0.087281
# 3        -1.170062  0.288663          -0.949875                   1.142704
# 4         1.229130  1.424586           0.141725                  -1.470222
#
#    Outlet_Size  Outlet_Type
# 0     0.307006    -0.151382
# 1     0.307006    -0.151382
# 2     0.307006    -1.991879
# 3     0.307006    -0.151382
# 4     0.307006     1.925057

# %%
data_test_predicted=knn.predict(Xtt_scaled)

# %%
data_test_predicted
# Out:
# array([1957.452  , 1245.7118 ,  639.70064, ..., 1451.84348, 4646.08556,
#        1323.87672])

# %% [markdown]
# These are the predicted values for the Bigmart test dataset.
